# %% [markdown]
# # Problem statement :
#
# - In this classification problem, you need address the following using data science techniques:
#     1. Address class imbalance issue and select the best technique.
#     2. Create a model to predict “Coverage Code” &amp; “Accident Source”.
#     3. Design a GUI that take the dataset file as input and will have a “Run” button to execute the model you created.
#     4. After executing the model, the GUI will summarize the evaluation results on the screen and store the excel file in a folder.

# %% [markdown]
# # Dataset Description :
# The dataset contains 190,000+ claim records with only one feature i.e., Claim description. The
# target columns are Coverage Code and Accident Source.

# %%
# import necessary libraries

import warnings
warnings.filterwarnings("ignore")
import pandas as pd
import re
import string
from string import digits
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
from sklearn import metrics
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score, precision_score, f1_score, recall_score
import pickle
import numpy as np
import time
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import (
    accuracy_score,
    classification_report,
    confusion_matrix,
    f1_score,
    recall_score,
)
from sklearn.model_selection import RandomizedSearchCV
from lightgbm import LGBMClassifier

# %%
# read data from excel format


data = pd.read_excel('./data/Dataset_Public.xlsx')

# %%
# glimpse of data

data.head(2)
# Out:
#                                    Claim Description Coverage Code  \
# 0  THE IV WAS MAKING A LEFT TURN ON A GREEN ARROW...            AN
# 1  CLAIMANT ALLEGES SHE SUFFERED INJURIES IN AN E...            GB
#
#               Accident Source
# 0  Struck pedestrian, bicycle
# 1          Elevator/Escalator

# %% [markdown]
# # Analysis of data:

# %%
print("Number of rows in dataset : ",data.shape[0])
# Out:
# Number of rows in dataset :  191690

# %% [markdown]
# ### feature : Claim Description

# %%
# general idea about features

data['Claim Description'].iloc[0]
# Out:
# 'THE IV WAS MAKING A LEFT TURN ON A GREEN ARROW WHEN A PEDESTRIAN  RAN INTO THE P/S OF IV. THE IV WAS DENTED ON THE FRONT P/S OF THE HOOD, THEN FELL BACKWARDS TO THE PAVEMENT. THE PEDESTRIAN         EXPERIENCED A LUMP ON HIS HEAD.'

# %% [markdown]
# Claim description is text features consist information about how loss occurred.

# %%
# find duplicates in feature

data['Claim Description'].duplicated().sum()
# Out:
# 27699

# %%
# get the value counts for same values

data['Claim Description'].value_counts()
# Out:
# CLAIMANT DROVE OVER POTHOLE CAUSING VEHICLE DAMAGE.                                                                                                                                            1057
# ROCK FROM ROAD - NO ONE AT FAULT                                                                                                                                                                598
# CLAIMANT DROVE OVER A POTHOLE CAUSING VEHICLE DAMAGE.                                                                                                                                           432
# PLAINTIFF ALLEGES INJURY CAUSED BY EMBEDDED BROKEN ARM OF PARAGARDIUD.                                                                                                                          311
# WATER DAMAGE                                                                                                                                                                                    291
#                                                                                                                                                                                                ...
# CUSTOMER WAS TEST DRIVING.  KEITH LUBRANO, OUR SALES REP WAS IN   THE PASSENGER SEAT.  THERE WAS A STOPPED VEHICLE IN THE ROAD AND  THEY WENT AROUND IT.  A TRUCK CLIPPED THE FRONT BUMPER.       1
# IV ON BROADWAY STREET SIGNALING A RIGHT TURN ONTO NEWTON STREET,  STRADDLING BOTH LANES SO THAT HE COULD MAKE A WIDE TURN , NO ONE  HURT , PICTURES AND VIDEO ARE ATTACHED.                       1
# DRYER PLUGGED IN WRONG CARRIER SAYS PLUGGED IN THERE BECAUSE OF   LEAKING VALVE, BELIEVES INSTALL DAMAGED VALVE 221222-014011                                                                     1
# I ENTERED PARKING LOT TO PARK, AND CAR BACKED INTO ME.                                                                                                                                            1
# WATER INTRUSION INTO THE BASEMENT LEVEL OF "ALL3 MEDIA" STORAGE UNITS.   ON TUESDAY, APRIL 11, 2023, AT APPROX. 10:30 PM THERE WAS A                                                              1
# Name: Claim Description, Length: 163990, dtype: int64

# %%
# lets check data with one of the duplicate value

data[data['Claim Description']=='CLAIMANT DROVE OVER POTHOLE CAUSING VEHICLE DAMAGE.']
# Out:
#                                         Claim Description Coverage Code  \
# 296     CLAIMANT DROVE OVER POTHOLE CAUSING VEHICLE DA...            GD
# 319     CLAIMANT DROVE OVER POTHOLE CAUSING VEHICLE DA...            GD
# 589     CLAIMANT DROVE OVER POTHOLE CAUSING VEHICLE DA...            GD
# 667     CLAIMANT DROVE OVER POTHOLE CAUSING VEHICLE DA...            GD
# 763     CLAIMANT DROVE OVER POTHOLE CAUSING VEHICLE DA...            GD
# ...                                                   ...           ...
# 191123  CLAIMANT DROVE OVER POTHOLE CAUSING VEHICLE DA...            GD
# 191265  CLAIMANT DROVE OVER POTHOLE CAUSING VEHICLE DA...            GD
# 191523  CLAIMANT DROVE OVER POTHOLE CAUSING VEHICLE DA...            GD
# 191550  CLAIMANT DROVE OVER POTHOLE CAUSING VEHICLE DA...            GD
# 191662  CLAIMANT DROVE OVER POTHOLE CAUSING VEHICLE DA...            GD
#
#        Accident Source
# 296            Pothole
# 319            Pothole
# 589            Pothole
# 667            Pothole
# 763            Pothole
# ...                ...
# 191123         Pothole
# 191265         Pothole
# 191523         Pothole
# 191550         Pothole
# 191662         Pothole
#
# [1057 rows x 3 columns]

# %%
# drop duplicates using claim description features

data.drop_duplicates(subset = ['Claim Description'],inplace = True)

# %%
# number of row after removing duplicate values

print("Number of rows in dataset : ",data.shape[0])
# Out:
# Number of rows in dataset :  163991

# %%
# check null values in claim description

data[data['Claim Description'].isna()]
# Out:
#     Claim Description Coverage Code         Accident Source
# 576               NaN            AD  Struck vehicle in rear

# %%
# remove null value from dataset

final_data = data[~data['Claim Description'].isna()]

final_data.shape
# Out:
# (163990, 3)

# %% [markdown]
# ## Data pre-processing:

# %%
def pre_processing(final_data):

    # Lowercase all characters
    final_data['Claim Description']=final_data['Claim Description'].apply(lambda x: x.lower())

    final_data['Claim Description'] = final_data['Claim Description'].apply(lambda x: re.sub(r"won\'t", "will not", x))
    final_data['Claim Description'] = final_data['Claim Description'].apply(lambda x: re.sub(r"can\'t", "can not", x))

    # general
    final_data['Claim Description'] = final_data['Claim Description'].apply(lambda x: re.sub(r"n\'t", " not", x))
    final_data['Claim Description'] = final_data['Claim Description'].apply(lambda x: re.sub(r"\'re", " are", x))
    final_data['Claim Description'] = final_data['Claim Description'].apply(lambda x: re.sub(r"\'s", " is", x))
    final_data['Claim Description'] = final_data['Claim Description'].apply(lambda x: re.sub(r"\'d", " would", x))
    final_data['Claim Description'] = final_data['Claim Description'].apply(lambda x: re.sub(r"\'ll", " will", x))
    final_data['Claim Description'] = final_data['Claim Description'].apply(lambda x: re.sub(r"\'t", " not", x))
    final_data['Claim Description'] = final_data['Claim Description'].apply(lambda x: re.sub(r"\'ve", " have", x))
    final_data['Claim Description'] = final_data['Claim Description'].apply(lambda x: re.sub(r"\'m", " am", x))

    # Remove quotes
    final_data['Claim Description']=final_data['Claim Description'].apply(lambda x: re.sub("'", '', x))



    exclude = set(string.punctuation) # Set of all special characters
    # Remove all the special characters
    final_data['Claim Description']=final_data['Claim Description'].apply(lambda x: ''.join(ch for ch in x if ch not in exclude))


    # Remove all numbers from text
    remove_digits = str.maketrans('', '', digits)
    final_data['Claim Description']=final_data['Claim Description'].apply(lambda x: x.translate(remove_digits))




    # remove extra
    final_data['Claim Description']=final_data['Claim Description'].apply(lambda x: re.sub('[-_.:;\[\]\|,]', '', x))


    # Remove extra spaces
    final_data['Claim Description']=final_data['Claim Description'].apply(lambda x: x.strip())

    final_data['Claim Description']=final_data['Claim Description'].apply(lambda x: re.sub(" +", " ", x))
    
    return final_data

# %%
final_data = pre_processing(final_data)

# %%
print('Row before pre-processing:')
print('*'*100)

print(data['Claim Description'].iloc[0])
print('='*100)
print('Row after pre-processing:')
print('*'*100)

print(final_data['Claim Description'].iloc[0])
# Out:
# Row before pre-processing:
# ****************************************************************************************************
# THE IV WAS MAKING A LEFT TURN ON A GREEN ARROW WHEN A PEDESTRIAN  RAN INTO THE P/S OF IV. THE IV WAS DENTED ON THE FRONT P/S OF THE HOOD, THEN FELL BACKWARDS TO THE PAVEMENT. THE PEDESTRIAN         EXPERIENCED A LUMP ON HIS HEAD.
# ====================================================================================================
# Row after pre-processing:
# ****************************************************************************************************
# the iv was making a left turn on a green arrow when a pedestrian ran into the ps of iv the iv was dented on the front ps of the hood then fell backwards to the pavement the pedestrian experienced a lump on his head

# %% [markdown]
# ## class_label 1 : Coverage Code

# %%
# find unique classes

print('Number of classes in Coverage code :',data['Coverage Code'].nunique())
# Out:
# Number of classes in Coverage code : 43

# %%
# import seaborn as sns
# import matplotlib.pyplot as plt

# # plot countplot of body_type and add count on each bar
# plt.figure(figsize=(30, 25))
# sns.countplot(y='Coverage Code', data=data)
# for p in plt.gca().patches:
#     plt.gca().annotate('{:.0f}'.format(p.get_height()), (p.get_x()+p.get_width()/2., p.get_height()), ha='center', va='center', xytext=(0, 10), textcoords='offset points')
# plt.show()

# %%
final_data['Coverage Code'].value_counts()
# Out:
# AD    43070
# GB    32193
# GD    22399
# AP    18894
# AL     9983
# AB     9397
# PA     8030
# PB     5089
# RB     4553
# NS     2297
# PM     1359
# AU     1273
# EL      855
# GK      632
# AN      558
# RC      514
# PI      384
# GO      337
# PL      317
# DC      261
# GL      237
# AM      224
# EP      184
# IK      183
# OM      138
# EO      137
# PP      112
# TE       85
# BM       66
# LL       57
# IM       40
# BL       36
# CM       30
# FB       18
# OI       14
# RF       12
# BR        6
# EB        4
# RQ        3
# FF        3
# LS        3
# EI        2
# PC        1
# Name: Coverage Code, dtype: int64

# %% [markdown]
# ## Observation :
#
# - There are 43 classes in Coverage code.
# - There is class imabalnce observed.
# - While few classes having very few data points.

# %% [markdown]
# ### Approach 1 :
#
# - Check classes with very few datapoints and create dictionary for features.
# - Check classes with medium range of datapoints and convert them into one class.
# - Develop model on new classes.
# - For medium range classes create one more model.
# - Use second model for prediction if class is in medium class.
# - Finally override decision if the feature is in dictionary of very few classes.

# %% [markdown]
# #### Step 1 : Create a dictionary for very fewer classes:

# %%
# check count of classes

coverage_code_classes = pd.DataFrame(final_data['Coverage Code'].value_counts())

# %%
very_few_classes = coverage_code_classes[coverage_code_classes['Coverage Code'] < 10].index.to_list()
medium_classes = coverage_code_classes[coverage_code_classes['Coverage Code'] < 1000].index.to_list()

# %%
# check the data with very few classes

fewer_data = final_data[final_data['Coverage Code'].isin(very_few_classes)]

fewer_data.head(2)
# Out:
#                                        Claim Description Coverage Code  \
# 33833  the caller states that the builder called and ...            BR
# 63005                 oil discovered in monitoring tanks            EI
#
#                            Accident Source
# 33833  Burglary, Robbery, Theft - Property
# 63005                                 Fuel

# %%
# for fewer classes either we can directrly create dictionary and use classes


fewer_class_dictionary = dict()
for idx,row in fewer_data.iterrows():
    
    fewer_class_dictionary[row[0]] = [row[1],row[2]]

fewer_class_dictionary
# Out:
# {'the caller states that the builder called and stated the items from the property that were being used to build the home were stolen and police report was created': ['BR',
#   'Burglary, Robbery, Theft - Property'],
#  'oil discovered in monitoring tanks': ['EI', 'Fuel'],
#  'eeoc charge of discrimination filed by current st john is university employee charles fortmann': ['EB',
#   'Alleged Discrimination'],
#  'allegations of violation of wage and hour violations limited assignment for payment of legal fees': ['EB',
#   'Alleged Negligent Act'],
#  'graffiti painted on wall': ['RQ', 'Other - comprehensive'],
#  'sewage release': ['EI', 'Backup Sewer, Seepage'],
#  'cyber breach': ['FF', 'Not Otherwise Classified'],
#  'claimant suffered defamation and loss of business': ['LS',
#   'Loss of Use, Business Interruption'],
#  'property theft and damage': ['BR', 'Burglary, Robbery, Theft - Property'],
#  'tools were stolen from a job site at francis howell north': ['BR',
#   'Burglary, Robbery, Theft - Property'],
#  'earthquake': ['RQ', 'Rain'],
#  'claimant suffered from abuse and attack': ['LS', 'Assault and/or abuse'],
#  'claimant is alleging theft and assets no injuries': ['FF',
#   'Burglary, theft - no forced entry'],
#  'neosho school dsitrict civil case summons for employee life insurance benefits': ['EB',
#   'Administrative Decision'],
#  'burst pipe in the production area': ['RQ',
#   'Sprinkler Leakage - Pipe or Head Failure'],
#  'slider doors stolen from job site': ['BR',
#   'Burglary, Robbery, Theft - Property'],
#  'winds lifted a section of the roof on the hickory co fema building': ['BR',
#   'Windstorm'],
#  'the caller reported that a door was broken into and installed appliances and tools were stolen': ['BR',
#   'Burglary, Robbery, Theft - Property'],
#  'leak from an ice machine caused damage to tenant is retail space below': ['PC',
#   'Building services, NOC'],
#  'claimant had financial loss': ['FF', 'Alleged Negligent Act'],
#  'alleged deformation and claimant is defamation claimant suffered stress anxiety': ['LS',
#   'Libel, slander - defamation'],
#  'morgan county rii school district district determined in an audit that they failed to pay employee contributions music has agreed to pay for the forensic audit': ['EB',
#   'Alleged Negligent Act']}

# %%
fewer_class_dictionary[fewer_data['Claim Description'].iloc[0]]
# Out:
# ['BR', 'Burglary, Robbery, Theft - Property']

# %% [markdown]
# #### Step 2 : Convert medium range classes into singl class

# %%
data_step_2 = final_data.copy()

def convert_class(feature):
    if feature in medium_classes:
        return 'med'
    else:
        return feature
    
final_data['Coverage Code'] = final_data['Coverage Code'].apply(convert_class)

# %%
final_data['Coverage Code'].value_counts()
# Out:
# AD     43070
# GB     32193
# GD     22399
# AP     18894
# AL      9983
# AB      9397
# PA      8030
# med     5453
# PB      5089
# RB      4553
# NS      2297
# PM      1359
# AU      1273
# Name: Coverage Code, dtype: int64

# %% [markdown]
# #### Step 3 : Develop a model on given classes :

# %% [markdown]
# ##### vectorization of feature

# %%
# create features and class label

X = final_data['Claim Description']

y = final_data['Coverage Code']

# %%
# split the dataset



X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20)

# %%
# convert data into vector form

count_vector_step_1 = CountVectorizer()

X_train = count_vector_step_1.fit_transform(X_train)
X_test = count_vector_step_1.transform(X_test)

# %%
# # usning tfidf vectorizer

# from sklearn.feature_extraction.text import TfidfVectorizer

# tfidf_vectorizer = TfidfVectorizer(use_idf=True)
# X_train_vectors_tfidf = tfidf_vectorizer.fit_transform(X_train) #tfidf runs on non-tokenized sentences unlike word2vec
# # Only transform x_test (not fit and transform)
# X_val_vectors_tfidf = tfidf_vectorizer.transform(X_test)

# %%
X_train.shape
# Out:
# (131192, 77557)

# %% [markdown]
# ##### Model 1 - naive bayes

# %%
# train
naive_bayes = MultinomialNB()
naive_bayes.fit(X_train, y_train)
print("Model trained")

# save model
path = "results/naive_bayes_step_1.pickle"
pickle.dump(naive_bayes, open(path, "wb"))
print("Model saved to", path)

# predict
y_pred = naive_bayes.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print('Accuracy for naive bayes :',np.round(accuracy,2))

print("*"*100)

target_names = naive_bayes.classes_
print(classification_report(y_test, y_pred, target_names=target_names))
print('*'*100)
# Out:
# Model trained
# Model saved to results/naive_bayes_step_1.pickle
# Accuracy for naive bayes : 0.69
# ****************************************************************************************************
#               precision    recall  f1-score   support
#
#           AB       0.60      0.19      0.29      1825
#           AD       0.62      0.83      0.71      8630
#           AL       0.79      0.90      0.84      1923
#           AP       0.58      0.35      0.44      3777
#           AU       0.47      0.48      0.47       259
#           GB       0.79      0.92      0.85      6438
#           GD       0.65      0.76      0.70      4566
#           NS       0.99      0.35      0.52       469
#           PA       0.85      0.87      0.86      1609
#           PB       0.90      0.49      0.64      1049
#           PM       1.00      0.06      0.11       277
#           RB       0.74      0.31      0.44       899
#          med       0.70      0.17      0.28      1077
#
#     accuracy                           0.69     32798
#    macro avg       0.75      0.51      0.55     32798
# weighted avg       0.70      0.69      0.66     32798
#
# ****************************************************************************************************

# %% [markdown]
# ##### Model 2 - logistic regression

# %%
from sklearn.linear_model import LogisticRegression

lr_basemodel =LogisticRegression()

lr_basemodel.fit(X_train, y_train)
print("Model trained")

# save model
path = "results/lr_step_1.pickle"
pickle.dump(lr_basemodel, open(path, "wb"))
print("Model saved to", path)

# predict
y_pred = lr_basemodel.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print('Accuracy for logistic regression :',np.round(accuracy,2))

print("*"*100)

target_names = lr_basemodel.classes_
print(classification_report(y_test, y_pred, target_names=target_names))
print('*'*100)
# Out:
# Model trained
# Model saved to results/lr_step_1.pickle
# Accuracy for logistic regression : 0.73
# ****************************************************************************************************
#               precision    recall  f1-score   support
#
#           AB       0.52      0.31      0.38      1825
#           AD       0.68      0.80      0.73      8630
#           AL       0.93      0.91      0.92      1923
#           AP       0.59      0.48      0.53      3777
#           AU       0.55      0.44      0.49       259
#           GB       0.82      0.90      0.86      6438
#           GD       0.73      0.77      0.75      4566
#           NS       0.84      0.75      0.79       469
#           PA       0.86      0.84      0.85      1609
#           PB       0.77      0.71      0.74      1049
#           PM       0.52      0.14      0.22       277
#           RB       0.66      0.61      0.63       899
#          med       0.52      0.27      0.36      1077
#
#     accuracy                           0.73     32798
#    macro avg       0.69      0.61      0.64     32798
# weighted avg       0.71      0.73      0.71     32798
#
# ****************************************************************************************************

# %%
# # using tfidf vectorizer

# lr_basemodel =LogisticRegression()

# lr_basemodel.fit(X_train_vectors_tfidf, y_train)
# print("Model trained")

# # save model
# path = "results/lr_step_1.pickle"
# pickle.dump(lr_basemodel, open(path, "wb"))
# print("Model saved to", path)

# # predict
# y_pred = lr_basemodel.predict(X_val_vectors_tfidf)

# accuracy = accuracy_score(y_test, y_pred)
# print('Accuracy for logistic regression :',np.round(accuracy,2))

# print("*"*100)

# target_names = lr_basemodel.classes_
# print(classification_report(y_test, y_pred, target_names=target_names))
# print('*'*100)

# %% [markdown]
# ##### Model 3 - hyper parameter tuning for random forest

# %%
#### model ####
# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start=200, stop=500, num=5)]
# Number of features to consider at every split
max_features = ["auto", "sqrt"]
# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(10, 110, num=5)]
max_depth.append(None)
# Minimum number of samples required to split a node
min_samples_split = [int(x) for x in np.linspace(10, 110, num=5)]
# Minimum number of samples required at each leaf node
min_samples_leaf = [int(x) for x in np.linspace(10, 110, num=5)]
# Method of selecting samples for training each tree
bootstrap = [True, False]
# Create the random grid

random_grid = {
    "n_estimators": n_estimators,
    "max_features": max_features,
    "max_depth": max_depth,
    "min_samples_split": min_samples_split,
    "min_samples_leaf": min_samples_leaf,
    "bootstrap": bootstrap,
}
print(random_grid)
# Out:
# {'n_estimators': [200, 275, 350, 425, 500], 'max_features': ['auto', 'sqrt'], 'max_depth': [10, 35, 60, 85, 110, None], 'min_samples_split': [10, 35, 60, 85, 110], 'min_samples_leaf': [10, 35, 60, 85, 110], 'bootstrap': [True, False]}

# %%
rf = RandomForestClassifier()
# Random search of parameters, using 3 fold cross validation,
# search across 100 different combinations, and use all available cores
rf_random = RandomizedSearchCV(
    estimator=rf,
    param_distributions=random_grid,
    cv=3,
    verbose=3,
    random_state=42,
    n_jobs=-1,
)

# %%
# fit random search

print("RF ..")
search_time_start = time.time()
rf_random.fit(X_train, y_train)
print("RF  time:", time.time() - search_time_start)
# Out:
# RF ..
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# RF  time: 549.3658676147461

# %%
# get best hyper parameter

rf_random.best_estimator_
# Out:
# RandomForestClassifier(max_depth=110, max_features='sqrt', min_samples_leaf=10,
#                        min_samples_split=35, n_estimators=200)

# %%
# train random forest model

clf_random = RandomForestClassifier(max_depth=110, max_features='sqrt', min_samples_leaf=10, min_samples_split=35, n_estimators=200)
clf_random.fit(X_train,y_train)
# Out:
# RandomForestClassifier(max_depth=110, max_features='sqrt', min_samples_leaf=10,
#                        min_samples_split=35, n_estimators=200)

# %%
# save model
path = "results/rf_basemodel.pickle"
pickle.dump(clf_random, open(path, "wb"))
print("Model saved to", path)

# predict
y_pred = clf_random.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print('Accuracy for random forest model :',np.round(accuracy,2))

print("*"*100)

target_names = clf_random.classes_
print(classification_report(y_test, y_pred, target_names=target_names))
print('*'*100)
# Out:
# Model saved to results/rf_basemodel.pickle
# Accuracy for random forest model : 0.59
# ****************************************************************************************************
#               precision    recall  f1-score   support
#
#           AB       1.00      0.04      0.07      1851
#           AD       0.51      0.97      0.67      8579
#           AL       0.96      0.81      0.88      1992
#           AP       0.83      0.04      0.07      3860
#           AU       0.00      0.00      0.00       262
#           GB       0.62      0.95      0.75      6408
#           GD       0.59      0.45      0.51      4408
#           NS       1.00      0.01      0.02       464
#           PA       0.92      0.61      0.73      1670
#           PB       0.98      0.17      0.29      1068
#           PM       1.00      0.04      0.07       262
#           RB       0.72      0.05      0.09       895
#          med       0.95      0.02      0.04      1079
#
#     accuracy                           0.59     32798
#    macro avg       0.78      0.32      0.32     32798
# weighted avg       0.70      0.59      0.51     32798
#
# ****************************************************************************************************

# %% [markdown]
# #### Observation :
#
# - Simple model like naive bayes and logistic regression having good performance.
# - While ensembel model like random forest not works good on dataset

# %% [markdown]
# #### Step 4 : Create a dataset with medium range class and train model

# %%
med_data = data_step_2[data_step_2['Coverage Code'].isin(medium_classes[:-5])]

med_data.head(2)
# Out:
#                                    Claim Description Coverage Code  \
# 0  the iv was making a left turn on a green arrow...            AN
# 9  claimant suffered bodily injury due to picked ...            EL
#
#               Accident Source
# 0  Struck pedestrian, bicycle
# 9          Fall - other falls

# %%
med_data.shape
# Out:
# (5441, 3)

# %%
med_data['Coverage Code'].value_counts()
# Out:
# EL    855
# GK    632
# AN    558
# RC    514
# PI    384
# GO    337
# PL    317
# DC    261
# GL    237
# AM    224
# EP    184
# IK    183
# OM    138
# EO    137
# PP    112
# TE     85
# BM     66
# LL     57
# IM     40
# BL     36
# CM     30
# FB     18
# OI     14
# RF     12
# BR      6
# EB      4
# Name: Coverage Code, dtype: int64

# %%
# create features and class label

X = med_data['Claim Description']

y = med_data['Coverage Code']

# %%
X_test.shape
# Out:
# (32798, 77557)

# %%
# split the dataset



X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20,stratify = y)

# %%
# convert data into vector form

count_vector_step_2 = CountVectorizer()

X_train = count_vector_step_2.fit_transform(X_train)
X_test = count_vector_step_2.transform(X_test)

# %%
# train
naive_bayes_2 = MultinomialNB()
naive_bayes_2.fit(X_train, y_train)
print("Model trained")

# save model
path = "results/naive_bayes_step_2.pickle"
pickle.dump(naive_bayes_2, open(path, "wb"))
print("Model saved to", path)

# predict
y_pred = naive_bayes_2.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print('Accuracy for naive bayes :',np.round(accuracy,2))

print("*"*100)

target_names = naive_bayes_2.classes_
print(classification_report(y_test, y_pred, target_names=target_names))
print('*'*100)
# Out:
# Model trained
# Model saved to results/naive_bayes_step_2.pickle
# Accuracy for naive bayes : 0.67
# ****************************************************************************************************
#               precision    recall  f1-score   support
#
#           AM       0.80      0.09      0.16        45
#           AN       0.54      0.84      0.66       112
#           BL       0.00      0.00      0.00         7
#           BM       0.00      0.00      0.00        13
#           BR       0.00      0.00      0.00         1
#           CM       0.00      0.00      0.00         6
#           DC       1.00      0.58      0.73        52
#           EB       0.00      0.00      0.00         1
#           EL       0.81      0.97      0.88       171
#           EO       0.65      0.41      0.50        27
#           EP       0.62      0.57      0.59        37
#           FB       0.00      0.00      0.00         4
#           GK       0.50      0.94      0.65       127
#           GL       0.85      0.70      0.77        47
#           GO       0.81      0.57      0.67        68
#           IK       0.97      0.76      0.85        37
#           IM       0.00      0.00      0.00         8
#           LL       1.00      0.09      0.17        11
#           OI       0.00      0.00      0.00         3
#           OM       1.00      0.11      0.19        28
#           PI       0.62      0.69      0.65        77
#           PL       0.91      0.65      0.76        63
#           PP       1.00      0.59      0.74        22
#           RC       0.61      0.71      0.66       103
#           RF       0.00      0.00      0.00         2
#           TE       0.00      0.00      0.00        17
#
#     accuracy                           0.67      1089
#    macro avg       0.49      0.36      0.37      1089
# weighted avg       0.69      0.67      0.63      1089
#
# ****************************************************************************************************

# %%
from sklearn.linear_model import LogisticRegression

lr_basemodel =LogisticRegression()

lr_basemodel.fit(X_train, y_train)
print("Model trained")

# save model
path = "results/lr_basemodel_step_2.pickle"
pickle.dump(lr_basemodel, open(path, "wb"))
print("Model saved to", path)

# predict
y_pred = lr_basemodel.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print('Accuracy for logistic regression :',np.round(accuracy,2))

print("*"*100)

target_names = lr_basemodel.classes_
print(classification_report(y_test, y_pred, target_names=target_names))
print('*'*100)
# Out:
# Model trained
# Model saved to results/lr_basemodel_step_2.pickle
# Accuracy for logistic regression : 0.72
# ****************************************************************************************************
#               precision    recall  f1-score   support
#
#           AM       0.34      0.27      0.30        45
#           AN       0.62      0.71      0.67       112
#           BL       0.50      0.29      0.36         7
#           BM       1.00      0.38      0.56        13
#           BR       0.00      0.00      0.00         1
#           CM       1.00      0.17      0.29         6
#           DC       0.82      0.81      0.82        52
#           EB       0.00      0.00      0.00         1
#           EL       0.86      0.95      0.91       171
#           EO       0.62      0.56      0.59        27
#           EP       0.56      0.62      0.59        37
#           FB       1.00      0.25      0.40         4
#           GK       0.76      0.81      0.78       127
#           GL       0.76      0.74      0.75        47
#           GO       0.75      0.56      0.64        68
#           IK       0.92      0.95      0.93        37
#           IM       0.00      0.00      0.00         8
#           LL       1.00      0.55      0.71        11
#           OI       1.00      0.33      0.50         3
#           OM       0.73      0.57      0.64        28
#           PI       0.73      0.69      0.71        77
#           PL       0.75      0.83      0.79        63
#           PP       0.62      0.68      0.65        22
#           RC       0.60      0.79      0.68       103
#           RF       0.00      0.00      0.00         2
#           TE       0.57      0.24      0.33        17
#
#     accuracy                           0.72      1089
#    macro avg       0.64      0.49      0.52      1089
# weighted avg       0.72      0.72      0.71      1089
#
# ****************************************************************************************************

# %% [markdown]
# #### Step 5 : Predict final output :

# %%
# load the different models from path

step_1_model_path = "results/lr_step_1.pickle"
step_2_model_path = "results/lr_basemodel_step_2.pickle"

step_1_model = pickle.load(open(step_1_model_path, 'rb'))
step_2_model = pickle.load(open(step_2_model_path, 'rb'))

# %%
# create predict function for predicting class label

def predict(model_1,model_2,final_dict,query):
    # predict
    
    test_1 =  count_vector_step_1.transform([query])
    y_pred = model_1.predict(test_1)
    if y_pred == 'med':
        test_2 =  count_vector_step_2.transform([query])
        y_pred = model_2.predict(test_2)
    else:
        y_pred = y_pred
        
    if query in final_dict.keys():
        y_pred = final_dict[query]
    else:
        y_pred = y_pred
        
    return y_pred[0]

# %%
# check predictions

final_result= []

test = data.sample(150)
test_data = pre_processing(test)
x_test = test_data['Claim Description']
for query in x_test:
    
    result = predict(step_1_model,step_2_model,fewer_class_dictionary,query)
    final_result.append(result)

# %%
# check the accuracy and other metrics

y_test_ = test['Coverage Code'].tolist()

accuracy = accuracy_score(y_test, y_pred)
print('Accuracy for logistic regression :',np.round(accuracy,2))

print("*"*100)


print(classification_report(y_test_, final_result))
print('*'*100)
# Out:
# Accuracy for logistic regression : 0.71
# ****************************************************************************************************
#               precision    recall  f1-score   support
#
#           AB       0.57      0.36      0.44        11
#           AD       0.74      0.84      0.79        38
#           AL       1.00      1.00      1.00         8
#           AN       0.00      0.00      0.00         2
#           AP       0.60      0.56      0.58        16
#           AU       0.00      0.00      0.00         2
#           EL       0.00      0.00      0.00         1
#           EO       1.00      1.00      1.00         1
#           GB       0.83      0.97      0.89        30
#           GD       0.62      0.75      0.68        20
#           GO       0.00      0.00      0.00         0
#           PA       1.00      1.00      1.00         3
#           PB       1.00      0.50      0.67         8
#           PI       0.00      0.00      0.00         0
#           RB       0.80      0.57      0.67         7
#           RC       1.00      0.50      0.67         2
#           RF       0.00      0.00      0.00         1
#
#     accuracy                           0.73       150
#    macro avg       0.54      0.47      0.49       150
# weighted avg       0.73      0.73      0.72       150
#
# ****************************************************************************************************

# %% [markdown]
# ## class_label 2 : Accident Source

# %%
# find unique classes

print('Number of classes in Coverage code :',data['Accident Source'].nunique())
# Out:
# Number of classes in Coverage code : 312

# %%
# import seaborn as sns
# import matplotlib.pyplot as plt

# # plot countplot of body_type and add count on each bar
# plt.figure(figsize=(30, 25))
# sns.countplot(y='Coverage Code', data=data)
# for p in plt.gca().patches:
#     plt.gca().annotate('{:.0f}'.format(p.get_height()), (p.get_x()+p.get_width()/2., p.get_height()), ha='center', va='center', xytext=(0, 10), textcoords='offset points')
# plt.show()

# %%
final_data['Accident Source'].value_counts()
# Out:
# Alleged Negligent Act            20254
# Sideswipe or lane change         15414
# Struck animal or object           7720
# Struck vehicle in rear            7400
# Not Otherwise Classified          7377
#                                  ...
# Machine - point of operation        14
# Insured Lost Control                14
# VEHICLE                             13
# Defective Pipework                  11
# Boiler, pressure vessel, etc.       10
# Name: Accident Source, Length: 312, dtype: int64

# %% [markdown]
# ## Observation :
#
# - There are 312 classes in Coverage code.
# - There is class imabalnce observed.
# - While few classes having very few data points.

# %%
# split the dataset



X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20)

# %%
# convert data into vector form

count_vector_step_1 = CountVectorizer()

X_train = count_vector_step_1.fit_transform(X_train)
X_test = count_vector_step_1.transform(X_test)

# %%
X_train.shape
# Out:
# (131192, 77721)

# %% [markdown]
# ##### vectorization of feature

# %%
# create features and class label

X = final_data['Claim Description']

y = final_data['Accident Source']

# %%
# split the dataset



X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20)

# %%
# convert data into vector form

count_vector_step_1 = CountVectorizer()

X_train = count_vector_step_1.fit_transform(X_train)
X_test = count_vector_step_1.transform(X_test)

# %%
# # usning tfidf vectorizer

# from sklearn.feature_extraction.text import TfidfVectorizer

# tfidf_vectorizer = TfidfVectorizer(use_idf=True)
# X_train_vectors_tfidf = tfidf_vectorizer.fit_transform(X_train) #tfidf runs on non-tokenized sentences unlike word2vec
# # Only transform x_test (not fit and transform)
# X_val_vectors_tfidf = tfidf_vectorizer.transform(X_test)

# %%
X_train.shape
# Out:
# (131192, 77556)

# %% [markdown]
# ##### Model 1 - naive bayes

# %%
# train
naive_bayes = MultinomialNB()
naive_bayes.fit(X_train, y_train)
print("Model trained")

# save model
path = "results/naive_bayes_as.pickle"
pickle.dump(naive_bayes, open(path, "wb"))
print("Model saved to", path)

# predict
y_pred = naive_bayes.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print('Accuracy for naive bayes :',np.round(accuracy,2))

print("*"*100)

target_names = naive_bayes.classes_
print(classification_report(y_test, y_pred, target_names=target_names))
print('*'*100)
# Out:
# Model trained
# Model saved to results/naive_bayes_as.pickle
# Accuracy for naive bayes : 0.34
# ****************************************************************************************************
#                                             precision    recall  f1-score   support
#
#     Accidental disposal of property/object       0.00      0.00      0.00        89
#                    Administrative Decision       0.00      0.00      0.00        21
#                                   Aircraft       0.00      0.00      0.00         5
#                     Alleged Discrimination       0.00      0.00      0.00        18
#                       Alleged False Arrest       0.00      0.00      0.00         8
#                           Alleged Incident       0.00      0.00      0.00        24
#       Alleged Misconduct - Personal Injury       0.00      0.00      0.00        21
#                      Alleged Negligent Act       0.25      0.85      0.39      4021
#          Alleged Violation of Civil Rights       0.00      0.00      0.00         7
# Alleged Violation of Civil Rights/Discrim.       0.00      0.00      0.00         9
#                    Alleged concrete defect       0.00      0.00      0.00        29
#          Alleged contamination or spoilage       0.54      0.44      0.48       410
#       Alleged damage to property of others       0.78      0.13      0.22       384
#                Alleged design flaw, defect       0.82      0.14      0.24       330
#          Alleged foreign object in product       0.62      0.66      0.64       460
#               Alleged improper formulation       0.00      0.00      0.00        14
#   Alleged improper maint.,park, playground       0.00      0.00      0.00         4
#   Alleged improper maintenance - municipal       0.00      0.00      0.00        71
#       Alleged improper maintenance - other       0.39      0.18      0.25       974
#     Alleged improper maintenance - schools       0.00      0.00      0.00        27
#  Alleged inadequate warnings, labels, etc.       0.00      0.00      0.00        11
#           Alleged installation by customer       0.00      0.00      0.00        10
#    Alleged installation by vendor/retailer       0.50      0.03      0.06        32
#                   Alleged lack of security       0.00      0.00      0.00        50
#    Alleged lack of supervision - municipal       0.00      0.00      0.00         3
#        Alleged lack of supervision - other       0.00      0.00      0.00        46
#      Alleged lack of supervision - schools       0.40      0.02      0.04        94
#    Alleged lack of supv., park, playground       0.00      0.00      0.00        12
#       Alleged mechanical defect of failure       0.00      0.00      0.00        50
#    Alleged product altered by manufacturer       0.00      0.00      0.00        17
# Alleged product altered by vendor/retailer       0.00      0.00      0.00        14
#                  Alleged product loss, NOC       1.00      0.29      0.45       126
#    Alleged product misused for application       0.00      0.00      0.00         3
# Alleged service or maint.- vendor/retailer       1.00      0.00      0.01       257
# Alleged service or maintenance by customer       0.00      0.00      0.00        20
#                          Allergic Reaction       0.50      0.01      0.02        79
#                             Animal, Insect       0.55      0.05      0.09       128
#                  Animal, Insect - Property       0.00      0.00      0.00        16
#                      Animal, Insect - W.C.       0.00      0.00      0.00        15
#                                   Asbestos       0.00      0.00      0.00         7
#                                    Assault       0.00      0.00      0.00       100
#                       Assault and/or abuse       0.00      0.00      0.00        57
#                Assault during apprehension       0.00      0.00      0.00        25
#                           Back up of sewer       0.00      0.00      0.00         7
#              Backed into vehicle or object       0.45      0.43      0.44      1197
#                      Backup Sewer, Seepage       0.00      0.00      0.00        17
#                                   Bathroom       0.00      0.00      0.00        32
#                                    Bicycle       0.00      0.00      0.00         5
#              Boiler, pressure vessel, etc.       0.00      0.00      0.00         1
#                                 Box Cutter       0.00      0.00      0.00         5
#                     Box, barrel, container       0.00      0.00      0.00        46
#              Breach of Data Protection Act       0.00      0.00      0.00         6
#                          Breaking up fight       0.00      0.00      0.00         6
#                     Building services, NOC       0.00      0.00      0.00        34
#        Burglary, Robbery, Theft - Property       0.00      0.00      0.00        63
#                   Burglary, robbery, theft       0.00      0.00      0.00       187
#          Burglary, theft - no forced entry       0.00      0.00      0.00        25
#                                   Car Wash       0.00      0.00      0.00       106
#                                   Car stop       0.00      0.00      0.00        23
#                                       Cart       0.81      0.21      0.34       462
#                                    Cave-in       0.00      0.00      0.00        10
#                           Ceiling Collapse       0.00      0.00      0.00         1
#                      Change in Temperature       0.00      0.00      0.00         3
#                       Chemicals - Property       0.00      0.00      0.00        13
#                      Circumstances Unknown       0.00      0.00      0.00        10
#                   Clothing, apparel, shoes       0.00      0.00      0.00        18
#                                   Collapse       0.00      0.00      0.00        14
#                                  Collision       0.00      0.00      0.00        41
#                  Collision on a Roundabout       0.00      0.00      0.00        39
#                 Collision with Oncoming TP       0.00      0.00      0.00        10
#                  Container - Packaging Etc       0.00      0.00      0.00         5
#     Contract Hauler Accident/Temp Employee       0.00      0.00      0.00         2
#                            DEFECTIVE FLOOR       0.00      0.00      0.00         5
#                         DEFECTIVE PAVEMENT       1.00      0.02      0.04        49
#                          DEFECTIVE PRODUCT       0.00      0.00      0.00        39
#                      DEFECTIVE WORKMANSHIP       0.00      0.00      0.00         6
#                           Damage - vehicle       0.00      0.00      0.00         7
#                      Damage to landscaping       0.72      0.18      0.29       308
#                         Defective Pipework       0.00      0.00      0.00         4
#                                    Display       0.00      0.00      0.00        53
#                          Display Furniture       0.00      0.00      0.00        10
#                                Door - Dock       0.00      0.00      0.00        10
#                              Door - Office       0.00      0.00      0.00        20
#                            Door/Door Catch       0.00      0.00      0.00        13
#                                   Drainage       0.00      0.00      0.00         4
#                    Driven over TP Property       0.00      0.00      0.00         7
#              EXACT CAUSE OF DAMAGE UNKNOWN       0.00      0.00      0.00         4
#                                 Electrical       0.00      0.00      0.00         9
#                           Electrical Fires       0.00      0.00      0.00         4
# Elevator,escalator,manlift,moving sidewalk       0.00      0.00      0.00        39
#                         Elevator/Escalator       0.00      0.00      0.00        27
#        Emissions of chemicals and/or gases       0.00      0.00      0.00         8
#                                   Employee       0.00      0.00      0.00         5
#           Entering or leaving traffic flow       0.00      0.00      0.00        99
#                      Equipment Malfunction       0.00      0.00      0.00        59
#                 Excavation, trench, tunnel       0.00      0.00      0.00        17
#                        Extreme temperature       0.00      0.00      0.00        34
#   Fall - hole/drain cover - defect/missing       0.00      0.00      0.00         1
#                         Fall - other falls       0.00      0.00      0.00         8
#                             Falling Object       0.00      0.00      0.00        95
#                                Fire - Auto       0.00      0.00      0.00        77
#                            Fire - Property       0.00      0.00      0.00        48
#                                Fire - W.C.       0.00      0.00      0.00         4
#                                      Flood       0.00      0.00      0.00        22
#                               Food Product       0.62      0.21      0.32       329
#                      Foreign object thrown       0.00      0.00      0.00        53
#                         Forklift accessory       0.00      0.00      0.00         3
#   Freezing of Plumbing, Heating, AC System       0.53      0.13      0.21       123
#                          Freight > 60 lbs.       0.00      0.00      0.00         3
#                             Frost/Ice/Snow       0.00      0.00      0.00         2
#                                       Fuel       0.00      0.00      0.00         7
#                         Furniture, fixture       0.00      0.00      0.00        63
#                             Gasoline spill       0.00      0.00      0.00        43
#                                Gate, fence       0.00      0.00      0.00        61
#              Glass wall or door with decal       0.00      0.00      0.00         8
#           Glass wall or door without decal       0.00      0.00      0.00         6
#                        Glass, ceramic, NOC       1.00      0.02      0.04        46
#                     Grease Fires - Kitchen       0.00      0.00      0.00         2
#                               Ground/floor       0.50      0.00      0.01       420
#                                       HOLE       0.00      0.00      0.00         9
#                                       Hail       0.00      0.00      0.00        39
#                     Hand tool, not powered       0.00      0.00      0.00         7
#                         Hand tool, powered       0.00      0.00      0.00         5
#                          Head-on collision       0.00      0.00      0.00        88
#                              Health Hazard       1.00      0.09      0.17        43
#                     Heating equipment, NOC       0.00      0.00      0.00         5
#                       Hit Inanimate Object       0.00      0.00      0.00         6
#                Hit Kerb/Island/Verge/Hedge       0.00      0.00      0.00         7
#                         Hit Object in Road       0.00      0.00      0.00         6
#                 Hit Post/Barrier/Gate/Pole       0.00      0.00      0.00        47
#                    Hit Third Party In Rear       0.00      0.00      0.00        40
#                            Hit Tree Branch       0.00      0.00      0.00         9
#                             Hit Wall/Fence       0.00      0.00      0.00        16
#             Hit Whilst Parked - Stationary       0.00      0.00      0.00        19
#                 Hit in Rear by Third Party       0.00      0.00      0.00        20
#                                       Hose       0.00      0.00      0.00         3
#                          Human Action, NOC       0.50      0.15      0.23       388
#                                  Hurricane       0.00      0.00      0.00         5
#                                        Ice       0.00      0.00      0.00        13
#                Ice, Snow, Sleet - Property       0.00      0.00      0.00        31
#                    Ice, Snow, Sleet - W.C.       0.00      0.00      0.00        29
#                                  Ice/water       0.00      0.00      0.00       288
#                                    Illness       1.00      0.04      0.08        25
#  Infectious, parasitic agents, NOC - Liab.       0.00      0.00      0.00         2
#   Injured while entering/alighting vehicle       1.00      0.02      0.03        66
#                      Insured Changed Lanes       0.00      0.00      0.00        24
#            Insured Emerged from Minor Road       0.00      0.00      0.00        13
#                      Insured Hit Parked TP       0.00      0.00      0.00        41
#                       Insured Lost Control       0.00      0.00      0.00         6
#                   Insured Reversing Hit TP       1.00      0.03      0.05        36
#             Insured Turned Against TP Path       0.00      0.00      0.00         6
#      Insured vehicle causes other accident       0.00      0.00      0.00        26
#                      Intersection accident       0.59      0.16      0.25       924
#                        Invasion of Privacy       0.00      0.00      0.00         5
#     Jacknife, rollover, overturned vehicle       0.00      0.00      0.00        88
#                                       KERB       0.00      0.00      0.00         7
#                                      Kiosk       0.00      0.00      0.00         1
#                                      Knife       0.00      0.00      0.00         5
#                          Ladder (portable)       0.00      0.00      0.00        13
#         Leak/Flood - Defective Maintenance       0.00      0.00      0.00         2
#           Leak/Flood - Defective Materials       0.00      0.00      0.00         1
#         Leak/Flood - Defective Workmanship       0.00      0.00      0.00         2
#                Libel, slander - defamation       0.00      0.00      0.00         3
#                                  Lightning       0.00      0.00      0.00        13
#                        Liquid/Grease Spill       0.00      0.00      0.00        11
#                         Liquids - Property       0.00      0.00      0.00        13
#                             Liquids - W.C.       0.00      0.00      0.00        25
#         Loss of Use, Business Interruption       0.00      0.00      0.00        10
#               Machine - point of operation       0.00      0.00      0.00         1
#                               Machine, NOC       0.00      0.00      0.00        17
#                         Malicious Mischief       0.00      0.00      0.00        24
#                              Manhole/Cover       0.00      0.00      0.00        13
#                            Manual Handling       0.00      0.00      0.00         8
#                                Merchandise       0.00      0.00      0.00        92
#                      Merchandises on Floor       0.00      0.00      0.00        52
#                            Metal item, NOC       0.00      0.00      0.00        42
#                  Misc - Object Hit Vehicle       0.00      0.00      0.00         5
#                           Misuse of weapon       0.00      0.00      0.00        15
#                                Mold/mildew       0.00      0.00      0.00        40
#                 Multiple Vehicle Collision       0.00      0.00      0.00         3
#              Natural Hazard-Non Vegetation       0.00      0.00      0.00         4
#                  Natural Hazard-Vegetation       0.00      0.00      0.00         7
#                                      Noise       0.00      0.00      0.00         3
#     Non Liability Cases - Premises Medical       1.00      0.06      0.12       109
#                       Non-contact accident       0.00      0.00      0.00        99
#                   Not Otherwise Classified       0.28      0.11      0.15      1403
#         Object fall - loading or unloading       0.00      0.00      0.00        51
#                            Object on floor       0.00      0.00      0.00       154
#             Office or Restaurant Furniture       0.00      0.00      0.00         2
#                              Oil or grease       0.00      0.00      0.00        75
#                                      Other       0.00      0.00      0.00         3
#                      Other - comprehensive       0.20      0.00      0.01       301
#                 Other vehicle turning left       0.00      0.00      0.00        76
#                Other vehicle turning right       0.00      0.00      0.00        42
#                    Our vehicle backed into       0.00      0.00      0.00       209
#     Our vehicle struck by object or animal       0.00      0.00      0.00       162
#      Our vehicle struck by runaway vehicle       0.00      0.00      0.00        57
#                 Our vehicle struck in rear       0.67      0.10      0.18       781
#            Our vehicle struck while parked       0.00      0.00      0.00       300
#                   Our vehicle turning left       0.00      0.00      0.00       200
#                  Our vehicle turning right       0.00      0.00      0.00        85
#                                     Pallet       0.00      0.00      0.00        36
#                       Pallet Jack (manual)       0.00      0.00      0.00        21
#                        Pallet Jack (power)       0.00      0.00      0.00         8
#                              Pallets/Skids       0.00      0.00      0.00         7
#                      Parking lot, driveway       0.00      0.00      0.00       270
#                    Particle/Foreign Object       0.00      0.00      0.00        30
#                             Patient, Child       0.00      0.00      0.00         9
#                                 Pharmacist       0.00      0.00      0.00         5
#                          Plastic item, NOC       0.00      0.00      0.00        12
#  Plumbing,Heating,AC,Discharge,Overflowing       0.49      0.42      0.45       186
#                                    Pothole       0.00      0.00      0.00        56
#                            Property Damage       0.00      0.00      0.00        15
#                                       Rain       0.00      0.00      0.00        51
#                            Ran off roadway       0.00      0.00      0.00        85
#                      Reversing/Manoeuvring       0.00      0.00      0.00        11
#                    Road Conditions/Weather       0.00      0.00      0.00         4
#                    Road debris/road hazard       0.63      0.24      0.34       313
#                            Runaway vehicle       0.00      0.00      0.00        28
#                              Scrap, debris       0.00      0.00      0.00        34
#                              Securing load       0.00      0.00      0.00        12
#                                      Sewer       0.00      0.00      0.00         7
#                               Sharp Object       0.00      0.00      0.00         8
#           Sharp objects (edges, splinters)       0.00      0.00      0.00        15
# Sharps(Needles,Razors,Scissors,Knife,etc.)       0.00      0.00      0.00        34
#                   Sideswipe or lane change       0.32      0.85      0.47      3048
#                                  Sink Hole       0.00      0.00      0.00         6
#                               Slip - other       0.00      0.00      0.00         8
#        Slip, Trip, Fall-Entering/Alighting       0.00      0.00      0.00        24
#                          Smoke - Liability       0.00      0.00      0.00         5
#         Soap, detergent, cleaning compound       0.00      0.00      0.00         4
#                                 Speed bump       0.00      0.00      0.00         1
#               Sprinkler Leakage - Freezing       0.00      0.00      0.00        15
#   Sprinkler Leakage - Pipe or Head Failure       0.00      0.00      0.00        40
#  Sprinkler Leakage-System Struck by Object       0.00      0.00      0.00         4
#                                     Stairs       0.00      0.00      0.00        60
#                          Stationary object       0.00      0.00      0.00       152
#                   Street, roadway, highway       0.00      0.00      0.00        92
#                    Struck animal or object       0.28      0.60      0.38      1492
#                  Struck building, overhang       0.20      0.01      0.02       311
#                   Struck by Falling Object       0.00      0.00      0.00         7
#                           Struck by Object       0.00      0.00      0.00        12
#                    Struck dock/garage door       0.00      0.00      0.00       106
#                  Struck dumpster enclosure       0.00      0.00      0.00       175
#                             Struck mailbox       0.50      0.01      0.02       223
#                              Struck object       0.00      0.00      0.00        25
#                      Struck parked vehicle       0.47      0.51      0.49      1409
#                 Struck pedestrian, bicycle       0.00      0.00      0.00       108
#                     Struck vehicle in rear       0.55      0.58      0.57      1492
#                   Struck/pulled down wires       0.84      0.30      0.45       305
#    Sudden stop or start, injuring occupant       0.89      0.45      0.60        89
#                              Swimming pool       0.00      0.00      0.00         6
#               T.P. Emerged from Minor Road       0.00      0.00      0.00         2
#                 T.P. Reversing hit Insured       0.00      0.00      0.00        11
#              TP Turned Across Insured Path       0.00      0.00      0.00         9
#                              Tarmac Defect       0.00      0.00      0.00         4
#                                   Textiles       0.00      0.00      0.00         4
#                                      Theft       0.57      0.18      0.27       263
#                  Third Party Changed Lanes       0.00      0.00      0.00        11
#                                    Tornado       0.00      0.00      0.00         5
#                                     Towing       0.00      0.00      0.00        17
#        Towing - Member Steered Incorrectly       0.00      0.00      0.00         5
#                             Towing - Other       0.00      0.00      0.00         6
#                        Trailer - Door/Seal       0.00      0.00      0.00         4
#                      Trailer - Rear/Bumper       0.00      0.00      0.00        10
#                Trapped in mechanical doors       0.00      0.00      0.00        15
#                                 Tree Roots       0.00      0.00      0.00         8
#                          Tree, bush, shrub       0.00      0.00      0.00        41
#                          Trip - kerb stone       0.00      0.00      0.00         4
#        Trip - raised manhole / drain cover       0.00      0.00      0.00         7
#                             Uneven Surface       0.00      0.00      0.00        78
#                                    VEHICLE       0.00      0.00      0.00         6
#   Vandalism and Malicious Mischief - Prop.       0.00      0.00      0.00        79
#    Vandalism and malicious mischief - W.C.       0.00      0.00      0.00        60
#                             Vehicle - Door       0.00      0.00      0.00        18
#       Vehicle - Material handling/forklift       0.00      0.00      0.00        23
#        Vehicle - Operated by injured party       0.00      0.00      0.00        10
#          Vehicle - Operated by other party       0.00      0.00      0.00        38
#                   Vehicle - Part/Accessory       0.00      0.00      0.00        12
#                             Vehicle - Seat       0.00      0.00      0.00         3
#                            Vehicle - Steps       0.00      0.00      0.00         6
#                     Vehicle - Tire/Retread       0.00      0.00      0.00        23
#                     Vehicle - Trailer body       0.00      0.00      0.00         8
#                              Vehicle - bus       0.00      0.00      0.00        21
#                 Vehicle - emergency - Fire       0.00      0.00      0.00         7
#               Vehicle - emergency - Police       0.00      0.00      0.00        11
#     Vehicle - motorcycle, moped, golf cart       0.00      0.00      0.00         4
#                        Vehicle - passenger       0.00      0.00      0.00        84
#        Vehicle - tractor, for semi trailer       0.00      0.00      0.00        48
#         Vehicle - truck, straight, pick-up       0.00      0.00      0.00        16
#                   Vehicle - truck/snowplow       0.00      0.00      0.00        72
#                              Vehicle - van       0.00      0.00      0.00         7
#                           Vehicle Accident       0.00      0.00      0.00       365
#                        Vehicle, unlicensed       0.00      0.00      0.00        57
#                       Walk, path, sidewalk       0.00      0.00      0.00        77
#                                      Water       0.00      0.00      0.00       134
#                               Water Damage       0.00      0.00      0.00        17
#                              Water Ingress       0.00      0.00      0.00         4
#                                     Weapon       0.00      0.00      0.00        21
#                     Weather NOC - Property       1.00      0.02      0.04        49
#                         Weather, NOC - W.C       0.00      0.00      0.00        10
#                 Weight of Ice, Snow, Sleet       0.00      0.00      0.00         6
#                    Wet/Greasy Floor/Ground       0.00      0.00      0.00         6
#                                 Wheelchair       0.00      0.00      0.00         5
#                                       Wind       0.00      0.00      0.00        23
#                                 Windshield       0.80      0.05      0.09       159
#                                  Windstorm       1.00      0.04      0.08       116
#                   Wire, cord, cable, chain       0.00      0.00      0.00        23
#                               Wood objects       0.00      0.00      0.00        22
#                            Working surface       0.00      0.00      0.00         6
#                             Wrongful entry       0.00      0.00      0.00        26
#                                 e-Commerce       0.89      0.53      0.67       460
#
#                                   accuracy                           0.34     32798
#                                  macro avg       0.10      0.03      0.03     32798
#                               weighted avg       0.34      0.34      0.26     32798
#
# ****************************************************************************************************

# %%
# check count of classes

accident_source_classes = pd.DataFrame(data_step_2['Accident Source'].value_counts())

# %%
accident_source_classes
# Out:
#                                Accident Source
# Alleged Negligent Act                    20254
# Sideswipe or lane change                 15414
# Struck animal or object                   7720
# Struck vehicle in rear                    7400
# Not Otherwise Classified                  7377
# ...                                        ...
# Machine - point of operation                14
# Insured Lost Control                        14
# VEHICLE                                     13
# Defective Pipework                          11
# Boiler, pressure vessel, etc.               10
#
# [312 rows x 1 columns]

# %%
very_few_classes_as = accident_source_classes[accident_source_classes['Accident Source'] < 20].index.to_list()
medium_classes_as = accident_source_classes[accident_source_classes['Accident Source'] < 100].index.to_list()

# %%
# check the data with very few classes

fewer_data_as = data_step_2[data_step_2['Accident Source'].isin(very_few_classes_as)]

fewer_data_as.head(2)
# Out:
#                                      Claim Description Coverage Code  \
# 485     claimant suffer property damage due to leakage            GD
# 545  a customer was buying bleach at aco around pm ...            GD
#
#                       Accident Source
# 485  Leak/Flood - Defective Materials
# 545         Container - Packaging Etc

# %%
# for fewer classes either we can directrly create dictionary and use classes


fewer_class_dictionary_as = dict()
for idx,row in fewer_data_as.iterrows():
    
    fewer_class_dictionary_as[row[0]] = [row[1],row[2]]

fewer_class_dictionary_as
# Out:
# {'claimant suffer property damage due to leakage': ['GD',
#   'Leak/Flood - Defective Materials'],
#  'a customer was buying bleach at aco around pm and the lid was not sealed properly and leaked on his pant while he was scanning products': ['GD',
#   'Container - Packaging Etc'],
#  'claimant was driving on the road and vehicle hit the speed bump causing vehicle damage': ['GD',
#   'Speed bump'],
#  'claimant suffered property damage due to flood': ['GD',
#   'Leak/Flood - Defective Workmanship'],
#  'devil is pool hot tub tracey got a rash on torso and back along with chills and body aches antibiotics were required': ['GB',
#   'Infectious, parasitic agents, NOC - Liab.'],
#  'claimant suffered property damaged due to dampness': ['GD',
#   'Leak/Flood - Defective Workmanship'],
#  'accident entre voiture derri re le magasin trop glissant alors ne pouvais pas freiner': ['AD',
#   'Frost/Ice/Snow'],
#  'claimant fall due to kerb and suffer the injuries': ['GB',
#   'Trip - kerb stone'],
#  'claimant suffered property damaged due to leakage': ['GD',
#   'Leak/Flood - Defective Materials'],
#  'claimant walking the road and tripped on a defective kerb causing injury': ['GB',
#   'Trip - kerb stone'],
#  'claimant cycling along path in a westerly direction when his bicycle wheel hit a sunken part of the road by a speed bump': ['GB',
#   'Speed bump'],
#  'caused damage to insured vehicle circumstances unknown': ['AP',
#   'EXACT CAUSE OF DAMAGE UNKNOWN'],
#  'guest stated that on september or he was leaving the parking lot and claimed that he hit a pothole he stated that it damaged the driver side of his jeep he also stated that he called and informed about the pothole to get fix': ['GD',
#   'Sink Hole'],
#  'umbrella allegedly fell due to wind and struck guest is wrist': ['GB',
#   'Natural Hazard-Non Vegetation'],
#  'customer purchase a can of spray paint placed it inn the back seat of his vehicle can of spray paint went off spraying the seats and door frame of his car': ['GD',
#   'Container - Packaging Etc'],
#  'a customer by the name of rainey miller called and complained about one of the delivery biker she said she was walking with herfriend on warren st when a delivery biker came out of nowhere andhit her with their bike and she fell to the ground she also said the biker was riding on the sidewalk and didnt even acknowledge her and just continued to ride away she had the bike number whichwas': ['GB',
#   'Bicycle'],
#  'member is key fob was damaged by an employee from the tire center': ['GD',
#   'Employee'],
#  'the iv was being taken to get washed the iv was struck by the ov as it was exiting a driveway turn': ['GK',
#   'Aircraft'],
#  'third party vehicle hit our vehicle in the rear causing our vehicle to hit the other tpv ahead': ['AD',
#   'Multiple Vehicle Collision'],
#  'claimant while working in organization suffered from asbestos causing injuries in chest': ['EL',
#   'Asbestos'],
#  'guest alleges she got ringworm from guest room linens guest notified hotel after departure': ['PM',
#   'Infectious, parasitic agents, NOC - Liab.'],
#  'claimant is property damaged due to leakage': ['GD',
#   'Leak/Flood - Defective Materials'],
#  'claimant reversed her car into the temporary traffic light unit atma operative allegedly left the base unitgenerator on the road and then walked off to set up cones elsewhere': ['GD',
#   'Other'],
#  'circumstances unclear road traffic collision spillage': ['AD',
#   'Multiple Vehicle Collision'],
#  'claimant tripped and fell due to a raised section of tarmac withinthe confines of the bus stop': ['GB',
#   'Tarmac Defect'],
#  'insured vehicle raising dock leveller caught shutter handle causing vehicle damage to insured': ['AP',
#   'Misc - Object Hit Vehicle'],
#  'asbestos exposure': ['GB', 'Asbestos'],
#  'insured bent over to connect a hose to the load and his back gave out sustained pain to his lower back': ['NS',
#   'Hose'],
#  'third party vehicle collided with insured vehicle causing loss anddamage': ['AB',
#   'Insured Turned Against TP Path'],
#  'claimant suffered property damage due to boiler leakage': ['GD',
#   'Boiler, pressure vessel, etc.'],
#  'the claimant has been in his kitchen and has tripped on a raised tile the claimant has sustained injury and loss': ['GB',
#   'DEFECTIVE FLOOR'],
#  'the claimant was walking to the door entrance when he tripped on the sidewalk and fell on his face': ['GB',
#   'Natural Hazard-Non Vegetation'],
#  'small pdclaimant alleges while iv was being towed by ov rd party iv ran over stone structure on property no injuries reported': ['AD',
#   'Contract Hauler Accident/Temp Employee'],
#  'water damage caused by leaking dishwasher': ['PB',
#   'Leak/Flood - Defective Materials'],
#  'claimant suffered property damage due to burst pipe': ['GD',
#   'Defective Pipework'],
#  'mbr complaint ee going through cart and the auditing of his cart item at the door stated he was calling head office': ['GB',
#   'Employee'],
#  'at approx pm i had reports of a poi going into the washroom with a backpack i asked security to follow up as i was with a customer at approx pm i met with the security guard near the back race track aisle and he advised that she was in': ['PI',
#   'Employee'],
#  'claimant suffered injury due to ceiling collapsed': ['GB',
#   'Ceiling Collapse'],
#  'claimant suffered property damage due to water leakage': ['GD',
#   'Leak/Flood - Defective Materials'],
#  'the cx purchased multiple cans of paint which she had tinted at our paint desk when she arrived home she found one of the quarts of chalk paint had come open and spilled all over her trunk and groceries': ['GD',
#   'Container - Packaging Etc'],
#  'we got our trailer customized from lcs and due to the recent snowfall in gta our number of trailers got collapsed lcs is not accepting their responsibility we will be claiming for our trailers kindly send an appraiser asap documentation to follows once adjuster is assigned': ['AP',
#   'Frost/Ice/Snow'],
#  'claimant fell due to drain hole causing injury': ['GB',
#   'Fall - hole/drain cover - defect/missing'],
#  'claimant is property damaged due to dampness': ['GD',
#   'Leak/Flood - Defective Materials'],
#  'the door to the trailer started going up really fast and insured fingers got slammed in trailer door': ['NS',
#   'Trailer - Door/Seal'],
#  'claimant states that while the forklift was loading his truck witha pallet of mulch one of the prongs from the forklift went through the driver side tail light': ['GD',
#   'Machine - point of operation'],
#  'tripped on a kerb stone which was significantly raised and dangerous': ['GB',
#   'Trip - kerb stone'],
#  'phv hit tpv in rear another tpv hit phv in rear': ['AP',
#   'Multiple Vehicle Collision'],
#  'josephine wright sun set drive lions bay was walking with her husband from the parking lot towards the entranceof the store she did not notice the speed bump and tripped over and injured her right eyebrow and right chick': ['GB',
#   'Speed bump'],
#  'phv hit rear of tpv into tpv': ['AD', 'Multiple Vehicle Collision'],
#  'impact damage when vehicle lost control': ['RB', 'VEHICLE'],
#  'our crew arrived back at the depot as the mate got out of the passenger door the wind took hold of it and bent the door back': ['AP',
#   'Other'],
#  'insured vehicle rolled over on national highways causing damaged to barrier': ['AD',
#   'Insured Lost Control'],
#  'upn ballast crews damaged nineteen parked and unoccupied vehicles at mp western ave lake forest il': ['GD',
#   'Machine - point of operation'],
#  'claimant suffered damage to coat as caught in escalators': ['GD', 'Other'],
#  'customers slipped on soap that another customer spilled on the floor and twisted her left ankle and hit her right knee': ['GB',
#   'Soap, detergent, cleaning compound'],
#  'claimant suffered injury due to ceiling fell on her head': ['GB',
#   'Ceiling Collapse'],
#  'insured vehicle tried to brake but due to the muddy road the insured vehicle slid and hit third party vehicle': ['AD',
#   'Insured Lost Control'],
#  'claimant tripped and fell due to kerb causing bodily injury': ['GB',
#   'Trip - kerb stone'],
#  'claimant suffered property damage due to roof had fallen': ['GD',
#   'Ceiling Collapse'],
#  'the claimant was ran over by a ton roller': ['GB',
#   'Machine - point of operation'],
#  'as jr driver was leaving the fuelling station the nsr of the trailer has made contact with the metal casing around fuel pump': ['AD',
#   'Misc - Object Hit Vehicle'],
#  'my father who is not fluent in english attempted to pay at the customer service desk he was met with an extremely aggressive response from one of your managers shahnaz shahnaz made disparaging remarks to my father saying are you blind stupid': ['PI',
#   'Employee'],
#  'elizabeth hartman who was seated at table when the leg of the chair broke causing her to fall down she is not claiming injury or': ['GB',
#   'Office or Restaurant Furniture'],
#  'grorcies in her hand basket a bottle of mean green antibacterical multi surface cleaner was open and spilled onto her groceries and her phone she wanted report filed just in case her phone is damag': ['GD',
#   'Soap, detergent, cleaning compound'],
#  'effected member sat down in a chair in the midway cpd office and said chair flipped over end causing member to fall to the ground causing pain to her backhipknees and tailbone the back of the chair further struck the member in the head causing discomfort member declined treatment at this time': ['NS',
#   'Office or Restaurant Furniture'],
#  'claimant fall in open drain causing bodily injury': ['GB',
#   'Fall - hole/drain cover - defect/missing'],
#  'lump of rock allegedly hit insured vehicle caused damage to vehicle': ['GD',
#   'Other'],
#  'claimant fell due to raised kirb stone causing injury': ['GB',
#   'Trip - kerb stone'],
#  'on july ms tidwell was driving her vehicle on bill gardner parkway approximately feet west of its intersection with strong rock parkway in the city of locust grove georgia as she was driving her vehicle a tree on the side of bill gardner parkway fell onto ms tidwell is vehicle causing her serious injuries she sustained injuries to her neck back head left arm and left leg along with continuing headaches': ['GB',
#   'Natural Hazard-Vegetation'],
#  'hirer lost control hit temporary concretemetal road works barrier': ['AD',
#   'Insured Lost Control'],
#  'sp damaged retaining wall which created a sink hole and also left tire marks in driveway no injury no police no tow': ['AD',
#   'Sink Hole'],
#  'customer emerged from aisle with his right thumb bleeding customer was provided first aid by nathan w in d customer spoke limited english but said he cut his finger on a nail tryingto compare it to one at home we could not locate the item': ['GB',
#   'Sharp Object'],
#  'david was standing on the side of the conveyor helping feed the new conveyor chain into the conveyor chute they had already pulledseveral sections into the chute': ['GB',
#   'Machine - point of operation'],
#  'claimant was waling outside the train station she tripped and felldue to cobble stone causing injury': ['GB',
#   'Trip - kerb stone'],
#  'possible asbestos exposure while completing renovations': ['NS', 'Asbestos'],
#  'fire started on stove in kitchen after school hours causing smoke damage to bldg': ['RB',
#   'Grease Fires - Kitchen'],
#  'mbr alleges wh employee damaged tires during the change of he contacted wh only on to report incident': ['GD',
#   'Employee'],
#  'paint spill in customer is vehicle they went around the corner and back seat is full of paint egyptian cotton sheet has paint paint is water solvable sku': ['GD',
#   'Container - Packaging Etc'],
#  'guest was projectile vomiting complaining about being hot and blacking out paramedics arrived and repeatedly asked guest if shehad taken edibles or pills or any other drugs the guest said no the paramedics stated that she must be on something to being acting that way that she was': ['GB',
#   'Natural Hazard-Non Vegetation'],
#  'customer returned to vehicle to find a large scratch on drivers side rear door claims it was not there when he entered store': ['GD',
#   'EXACT CAUSE OF DAMAGE UNKNOWN'],
#  'member alleges a cart pusher came at him and that his item was touched by an employee': ['GB',
#   'Employee'],
#  'claimant fell onto uneven road service with small sink holes in the lane causing injury': ['GB',
#   'Sink Hole'],
#  'potential exposure to asbestos in the franklin park maintenance ofway building': ['NS',
#   'Asbestos'],
#  'claimant ran wood through a saw backwards and cut hands': ['GB',
#   'Machine - point of operation'],
#  'sally cruver was visiting another guest francis redmond in his room and upon getting out of the chair she slipped and fell': ['GB',
#   'Office or Restaurant Furniture'],
#  'maries co rii school district donna was delivering flowers fell on entry steps breaking vase and cutting fingers on left hand and has pain in elbow': ['GB',
#   'Natural Hazard-Non Vegetation'],
#  'in the performance of his duty ff lainskas leading out a hose line injured his right thumb': ['NS',
#   'Hose'],
#  'claimant suffered property damage due to dampness and water leakage': ['GD',
#   'Leak/Flood - Defective Workmanship'],
#  'insured entered the roundabout across path of third party causing vehicle damage': ['AD',
#   'Insured Turned Against TP Path'],
#  'clmt alleges fell in manhole causing damage to key fob injury to left ankle hip bg had not done work in area over months': ['GB',
#   'Sink Hole'],
#  'the customer purchased behr masonry stucco and brick paint and used it to paint the tiles inside their shower they discovered that this is not the correct product for the job they have advised that an associate recommended the product to be used': ['PB',
#   'Employee'],
#  'claimant is property damaged due to radiator leakage': ['GD',
#   'Leak/Flood - Defective Materials'],
#  'customer went to use the hand sanitizer located at the express lanes when she pushed on the nozzle instead of the liquid squirting down into her hands it squirted out into her both her left and right eye the nozzle was clogged': ['GB',
#   'Soap, detergent, cleaning compound'],
#  'the claimant stated she was dx with e coli times since may as a result of ingesting tap water in her apartment': ['GB',
#   'Infectious, parasitic agents, NOC - Liab.'],
#  'cliente enceinte assise sur les sacs de sel en caisse centraleen se levant a cote de son marie elle s evanoue elle reprend vite connaissance et refuse vite lappel avec son marie': ['GB',
#   'EXACT CAUSE OF DAMAGE UNKNOWN'],
#  'customer purchased some glidden essentials paint that was tinted and some spilled on his back floor mat and hoodie sleeve': ['GD',
#   'Container - Packaging Etc'],
#  'claimant suffered property damage due to the ceiling falling and flooding': ['GD',
#   'Ceiling Collapse'],
#  'i tripped and fell on kicking huge sinkhole about ft away from the curb': ['GB',
#   'Fall - hole/drain cover - defect/missing'],
#  'maintenance manager luis danny sandoval was in the back office and hit his head on the cabinet door he left open above the mainte': ['GB',
#   'Office or Restaurant Furniture'],
#  'mbr years old son slipped and fell as he was exiting their vehicle fell on buttocks and hit his back against truck': ['GB',
#   'Frost/Ice/Snow'],
#  'the customer alleges the ee caused damage to rub rails to the trailer while unloading the pallets': ['GD',
#   'Aircraft'],
#  'the door to the trailer started going up and smashed insureds fingers in the trailer door': ['NS',
#   'Trailer - Door/Seal'],
#  'customer injured himself on the finger after he lifted the white shelvingwas sharp around the edges which was cut to the length that customer requested was bleeding because of the cut': ['GB',
#   'Sharp Object'],
#  'the temp emp was stepping off the back of the truck and twisted his right ankle the temp emp then walked away from the location': ['AB',
#   'Contract Hauler Accident/Temp Employee'],
#  'while the truck was heading east the two trucks were going the opposite direction of each other when a piece of concrete went through the windshield and struck the temp emp the temp emp sustained some scrapes and bleeding on his bicep': ['AB',
#   'Contract Hauler Accident/Temp Employee'],
#  'insured vehicle gets hit in rear causing to move and hit another third party vehicle causing vehicle damage to third party': ['AD',
#   'Multiple Vehicle Collision'],
#  'personal injury claimant sustained injuries when he was disembarking flight from perth to telfer': ['GB',
#   'DEFECTIVE FLOOR'],
#  'ceva contracted driver dropped trl on tues at amazon and went back on noticed that the trailer swing door was knocked off the hinges driver does not know who damaged provided erika with the guard shack at amazon is': ['AP',
#   'Trailer - Door/Seal'],
#  'mbr was filling his vehicle ar the gas pump when a piece of ice fell from the canopy': ['GB',
#   'Frost/Ice/Snow'],
#  'claimants trainer got caught in the hazard and claimant fell to the ground': ['GB',
#   'Other'],
#  'an employee was test driving the iv when the ov merged and struck the ds iv causing the ds front': ['GK',
#   'Aircraft'],
#  'a guest was getting out of their vehicle when she fell after observing the parking lot there is what looks to be tree roots growing under the asphalt causing it to leave a hole along with a ripple in the parking lot': ['GB',
#   'Natural Hazard-Vegetation'],
#  'client hit stationary third party causes multiple collision': ['AD',
#   'Multiple Vehicle Collision'],
#  'claimant lost his footing on a defective utility cover causing him to fall sustain injuries': ['GB',
#   'Fall - hole/drain cover - defect/missing'],
#  'an employee was riding a customer motorcycle lost control and struck another customer vehicle the': ['GK',
#   'Aircraft'],
#  'insured vehicle turn for back lane and hit third party vehicle causing vehicle damage': ['AD',
#   'Insured Turned Against TP Path'],
#  'on september mr tran was involved in a motor vehicle collision caused by a thirdparty t': ['GO',
#   'Aircraft'],
#  'asbestos claim': ['PA', 'Asbestos'],
#  'mbr slipped and fell on a patch of ice in handicapped parking space': ['GB',
#   'Frost/Ice/Snow'],
#  'small pd while the iv was servicing a customer the iv experienced mechanical issues causing the iv to leak anti freeze onto the asphalt and into the sewers there was no damage to the iv with no reported injuries': ['AL',
#   'Leak/Flood - Defective Materials'],
#  'this morning the driver had some issue because of bad weather andicy road when he tried to park his truck in the customer is entrance for po the truck slid and hit the neighbour is carshelter': ['GD',
#   'Frost/Ice/Snow'],
#  'damage caused to insured vehicle circumstances unknown': ['AP',
#   'EXACT CAUSE OF DAMAGE UNKNOWN'],
#  'insured vehicle was parked someone bashed door caused vehicle damage': ['AP',
#   'EXACT CAUSE OF DAMAGE UNKNOWN'],
#  'insured vehicle hit third party vehicle causing injury': ['AB',
#   'Insured Turned Against TP Path'],
#  'while advancing a hose line into the basement of a residential house fire capt hanson conducted a primary search of the basement looking for victims as he made his way back up the stairs he stepped on the hose line and fell on the stairs twisting his right ankle and left knee': ['NS',
#   'Hose'],
#  'while participating in the chicago police department hour bicycle certification and crown control course ppo viramontes was operating his cpd issued bicycle and was performing a halfdismount required maneuver when he fell off his bicycle striking his right leg on the floor ppo viramontes immediatelyfelt pain and observed minor bruising his right leg': ['NS',
#   'Bicycle'],
#  'iv driver was traveling eastbound when he lost control of the vehicle and the iv landed on the side of a road in a ditch no injuries were reported': ['AP',
#   'Insured Lost Control'],
#  'handle area of knife has scratches on it from knife sharpener i am sure the laser was on the beveled edge on knife because i asked the customer to step aside so i could see to line it up': ['GD',
#   'Machine - point of operation'],
#  'claimant drove over speed bump causing vehicle damage': ['GD', 'Speed bump'],
#  'while performing his duties at a lt woods felt his right ring finger being bent backwards while advancing a hoseline': ['NS',
#   'Hose'],
#  'claimant vehicle damage due to a sink hole': ['GD', 'Sink Hole'],
#  'driver opened cab door felt a sharp cut to right thumb bus reg bledf': ['EL',
#   'Sharp Object'],
#  'personal injury claimant right foot caught the edge of the doorway into the donga and she tripped and fell forward inside the donga': ['GB',
#   'DEFECTIVE FLOOR'],
#  'customer came outside to the parking lot and noticed that his car had been hit there was damage to the back left bumper of his vehicle while collecting the customers information for the claim the customer declined to share his insurance information': ['GD',
#   'EXACT CAUSE OF DAMAGE UNKNOWN'],
#  'driver went over bump when he got of from bus felt pain in back bus reg snlho': ['EL',
#   'Speed bump'],
#  'claimant suffered property damage due water ingress': ['GD',
#   'Leak/Flood - Defective Workmanship'],
#  'falling stones from third party vehicle hit insured vehicle causing insured vehicle damage': ['AP',
#   'Misc - Object Hit Vehicle'],
#  'ear started clogging on the flight to romania worked to scotlandonto new hamshire i called scheduling and advised i was sick and would need to be removed i had a family member pick me up in bwii went to urgent care saw an ame had a follow up a week later following week went to my doctor i was advised should see an otolaryngologist it is possible according to the doctors i flew sick making it a deep inner ear clog': ['NS',
#   'Aircraft'],
#  'while on tga boulevard servicing a customer the temp emp dropped a bottle reached to get the bottle and left his hand on the hopperthe hopper pressed down on the temp emp hand and he sustained a laceration which required stitches to his left hand': ['AB',
#   'Contract Hauler Accident/Temp Employee'],
#  'heavy rains resulted in the flooding of iv': ['AP',
#   'Natural Hazard-Non Vegetation'],
#  'claimant fell into the inspection pit suffered injuries': ['EL',
#   'DEFECTIVE FLOOR'],
#  'claimant tripped walking on uneven tarmac path causing bodily injury': ['GB',
#   'Tarmac Defect'],
#  'claimant exposure to asbestos occurred in the course of his employment': ['EL',
#   'Asbestos'],
#  'claimant suffered damage to property due to water leak': ['GD',
#   'Leak/Flood - Defective Materials'],
#  'claimant suffered injury due to motorcycle fall': ['GB',
#   'Road Conditions/Weather'],
#  'purchase carrier said switcher signaled good to go and purchase carrier pulled trailer off door but package handler was inside noinjury no tow no police': ['AD',
#   'Trailer - Door/Seal'],
#  'claimant suffered property damaged due to speed humps': ['GD', 'Speed bump'],
#  'mbr got out of his vehicle took a few steps slipped fell he alleges he hit his head cctv would show he did not fall': ['GB',
#   'Frost/Ice/Snow'],
#  'claimant suffered property damage due to blockage': ['GD',
#   'Defective Pipework'],
#  'possible exposure to asbestos tile': ['NS', 'Asbestos'],
#  'alleged damage to motor vehicle': ['GD', 'Other'],
#  'insured collided with third party vehicle caused injury': ['AB',
#   'Insured Turned Against TP Path'],
#  'visitor was walking in grass by the laundry facility she slipped and fell': ['GB',
#   'Natural Hazard-Vegetation'],
#  'staff member while doing freezer temp put probe in butter pot it went right through and stabbed her in the hand': ['EL',
#   'Sharp Object'],
#  'customer reported that she was loading her car and noticed the bottle of clorox bleach was spraying and sprayed all over her shirt and shoes the bleach soaked through her shirt and went ontoher skin which caused skin irritation': ['PA',
#   'Container - Packaging Etc'],
#  'claimant daughter suffered injury due to defective flooring': ['GB',
#   'DEFECTIVE FLOOR'],
#  'during a storm member is tree was uprooted and fell onto their ownfence the roof of the neighbor is house and the neighbor is fence': ['GD',
#   'Natural Hazard-Vegetation'],
#  'while participating in the chicago police department hour bicycle certification and crown control course officer hernandezherrera fell to the ground while attempting to mount hisbicycle striking his left knee on the floor officer hernandezherrera immediately felt pain and soreness to his left knee officer hernandezherrera refused medical treatment at time of injury': ['NS',
#   'Bicycle'],
#  'claimant fall over drain causing bodily injury': ['GB',
#   'Fall - hole/drain cover - defect/missing'],
#  'guest riding resort bicycle and fell': ['GB', 'Bicycle'],
#  'claimant suffered property damage due to leakage from boiler': ['GD',
#   'Boiler, pressure vessel, etc.'],
#  'claimant stepped in a hole causing injury': ['EL',
#   'Fall - hole/drain cover - defect/missing'],
#  'husband reaching for another product that was out of reach locatedfurther back of the shelf and he knocked over a bottle on the floor and contents splashing on my face and my eyes both': ['GB',
#   'Container - Packaging Etc'],
#  'claimant suffered bodily injury due to tripped onto raised cobbles': ['GB',
#   'Trip - kerb stone'],
#  'katherine called and said she purchased gallons of paint she claimed can was not closed properly and spilled in the back of her car it spilled onto clothing and upholstery of her vehicle': ['GD',
#   'Container - Packaging Etc'],
#  'michel therrien artisans loc therrien amp fils cetait une nouvelle route puis le chauffeur a du deacuteplacer le conteneurplus loin dans la cours la cours eacutetait tres glissante voir photo en reculant le camion a glisseacute et le pneu arriegravere a eacuteteacute directement sur le pare choc arriegravere du tiers constat faitvoir photo dans preuve pasde blesser camion aucun dommage veacutehicule du tier endommageacute voir photo dans pre': ['AD',
#   'Road Conditions/Weather'],
#  'claimant suffered property damage due to pipe burst and caused ceiling to collapse': ['GD',
#   'Ceiling Collapse'],
#  'tenant was cooking and grease fire started in kitchen loss occurred at west martin luther king street swainsboro ga': ['RB',
#   'Grease Fires - Kitchen'],
#  'as claimants vehicle went over device loud noise with plastic shout and cable was warp around undercarriage of car': ['GD',
#   'Other'],
#  'possible asbestos exposure while on rehab project': ['NS', 'Asbestos'],
#  'delivery of pallets to advance auto parts store after delivery iwas pulling the trailer door in other to close properly sharp pain at upper back of my neck back and left side': ['NS',
#   'Trailer - Door/Seal'],
#  'claimant is property damage due to leakage': ['GD',
#   'Leak/Flood - Defective Materials'],
#  'personal injury plaintiff sustained personal injuries while carrying out his employment': ['GB',
#   'DEFECTIVE FLOOR'],
#  'claimant fell over a draingrate broken her left elbow claimant suffered injury': ['GB',
#   'Fall - hole/drain cover - defect/missing'],
#  'customer on wrong side of road and hit third party vehicle causingvehicle damage': ['AD',
#   'Insured Turned Against TP Path'],
#  'while customer was attempting installation without gloves or ppehe had dropped a screw and when attempting to retrieve the screw the range hood slipped and lacerated the back of his right hand severing tendons and nerves': ['PA',
#   'Sharp Object'],
#  'due to heavy winds and storms while loaner vehicle was parked andunoccupied a tree branch fell on the drivers side top of the roofclose to the door of the vehicle causing damage': ['AP',
#   'Natural Hazard-Vegetation'],
#  'structural and sinking issues': ['RB', 'Sink Hole'],
#  'claimant tripped at a drain cover causing bodily injury': ['GB',
#   'Fall - hole/drain cover - defect/missing'],
#  'claimant while walking tripped on a raised kerb stone and sustain injury': ['GB',
#   'Trip - kerb stone'],
#  'resident allegedly tripped over an exposed root and broke her ankle': ['GB',
#   'Natural Hazard-Vegetation'],
#  'claimant suffered property damage due to defective pipe work': ['GD',
#   'Defective Pipework'],
#  'claimant suffered property damage due to ceiling leak': ['GD',
#   'Leak/Flood - Defective Workmanship'],
#  'possible exposure to asbestos': ['NS', 'Asbestos'],
#  'resident tripped and fell': ['GB', 'Natural Hazard-Vegetation'],
#  'guest slipped on the wet floor and fell he was holding a beer bottle in one hand and it broke when he fell and cut his hand elbow': ['GB',
#   'Soap, detergent, cleaning compound'],
#  'third party struck to insured vehicle which causes insured hit another third party vehicle': ['AD',
#   'Multiple Vehicle Collision'],
#  'insured named in summons claimant alleges mesothelioma and asbestos related heath conditions due to exposure of asbestos contaminated product': ['GB',
#   'Asbestos'],
#  'plaintiff was exposed to asbestos dust from asbestos containing products that were present utilized on defendent is premises': ['GB',
#   'Asbestos'],
#  'claimant reports that a rock fell from the union pacific diversey st bridge and cracked his vehicle is windshield': ['GD',
#   'Natural Hazard-Non Vegetation'],
#  'claimant drove over uneven road causing vehicle damage claimant suffered property damage': ['GD',
#   'Road Conditions/Weather'],
#  'while at the scene of a working fire lt kelly was assisting companies move hose when he felt something pull in his abdomenlt kelly was transported by ambulance to be evaluated': ['NS',
#   'Hose'],
#  'insured vehicle damage due to fallen object by third party vehicle': ['AU',
#   'Misc - Object Hit Vehicle'],
#  'claimant is property damaged due to mould and asbestoses': ['GD',
#   'Asbestos'],
#  'insured found damage to vehicle while parked in yard': ['AP',
#   'EXACT CAUSE OF DAMAGE UNKNOWN'],
#  'mulitple collision spillage': ['AD', 'Multiple Vehicle Collision'],
#  'guest member of health club was splashed with disinfectant whilecleaning her bike': ['PM',
#   'Soap, detergent, cleaning compound'],
#  'claimant vehicle damage due to road defect': ['GD',
#   'Road Conditions/Weather'],
#  'sur sub contractor crew member working with indus employees pumping concrete employees were clearing a clogged hose hose jumped upward and hit sur employee facehead': ['GB',
#   'Hose'],
#  'our client stepped in a hole in the ground tripped and fell': ['GB',
#   'Natural Hazard-Non Vegetation'],
#  'per supervisor ee inhaled chemicals after mixing toilet bowl cleaner with bleach': ['NS',
#   'Soap, detergent, cleaning compound'],
#  'our driver swapped lanes and hit third party vehicle causing damaged': ['AD',
#   'Insured Turned Against TP Path'],
#  'the contracted vehicle was backing to the compactor when its rear door struck the control room there were no injuriesreported there was minor damage to the control room': ['AD',
#   'Contract Hauler Accident/Temp Employee'],
#  'insured vehicle mirror popped out without hitting anything insured driving along a rough track': ['AP',
#   'Road Conditions/Weather'],
#  'impact damage unknown party': ['RB', 'VEHICLE'],
#  'claimant alleges to have tested positive for covid it is unknown how it was contracted claimant is an employee': ['GB',
#   'Infectious, parasitic agents, NOC - Liab.'],
#  'unknown personnel put some liquid on top of the router box that was leaking and caused damage into the router no injuries no vehicles involve': ['AD',
#   'Machine - point of operation'],
#  'fela connecting car air hose to engine air hose pulled back to kink hose and felt a pop in right arm': ['NS',
#   'Hose'],
#  'claimant suffered asbestosis during the course of employment': ['EL',
#   'Asbestos'],
#  'claimant suffered property damage due to boiler damage': ['GD',
#   'Leak/Flood - Defective Workmanship'],
#  'enclosed is a summons cover sheet and complaint collectively the lawsuit which were personally served on landlord on ma': ['GB',
#   'Office or Restaurant Furniture'],
#  'on a rainy day mbr slipped and fell as he placed his foot on the top of a speed bump': ['GB',
#   'Speed bump'],
#  'claimant suffered property damage due to leakage from water tank': ['GD',
#   'Leak/Flood - Defective Workmanship'],
#  'alleged internal damage due to water leaking down the wall from the down pipe being moved during our works': ['GD',
#   'Other'],
#  'a jed driver was reaching for the strap on the trailer door not noticing the receiver was already bringing down the trailer door causing the door to close on the driver is left hand': ['GB',
#   'Trailer - Door/Seal'],
#  'mbr tripped and fell on a speed bump delimiting area where carts are stored outside wh not a cart corral in parking': ['GB',
#   'Speed bump'],
#  'circumstances are not specified': ['AP', 'EXACT CAUSE OF DAMAGE UNKNOWN'],
#  'small pda third party was hauling a iv transfer trailer to the recycle america location and the driver noticed that a wheel had came off the transfer trailer': ['RB',
#   'Contract Hauler Accident/Temp Employee'],
#  'officer viramotes was a participant in the chicago police o hour bicycle crowd control course officer viramontes was riding on a chicago police issued bicycle during training during the training officer viramotes was completing the slalom bicycle drilland was attempting to dismount his bicycle when he lost his footing and fell to the floor injuring his left knee and his left hand ring finger baby finger officer viramotes was asked by officer spears if he needed': ['NS',
#   'Bicycle'],
#  'ee is helping load patio set into mbr veh and pushed prod into bed of truck caused struts supporting tonneau cover to break': ['GD',
#   'Misc - Object Hit Vehicle'],
#  'claimant alleges that he hit a large black rock by the excavation with his tyre causing tyre to pop': ['GD',
#   'Other'],
#  'insured vehicle turned across path hit third party causing vehicledamage': ['AD',
#   'Insured Turned Against TP Path'],
#  'claimant fall due to uneven floor causing damage': ['GB', 'DEFECTIVE FLOOR'],
#  'claimant suffered property damage due to ceiling collapse': ['GD',
#   'Ceiling Collapse'],
#  'dead tree limb fell on guest vehicle': ['GD', 'Natural Hazard-Vegetation'],
#  'driver had fallen over ice causes injuries to right shoulder': ['EL',
#   'Frost/Ice/Snow'],
#  'customer sprayed with cleaner on hand and put finger in mouth and had some in his eyes': ['GB',
#   'Soap, detergent, cleaning compound'],
#  'there was a fire in the kitchen of the insured location there were no injuries stove left center and right upper cabinet vent pipes range hood counter top and backsplash and sheet rockall need to be replaced': ['RB',
#   'Grease Fires - Kitchen'],
#  'claimant tripped and fell on a raised area of tarmac beside a treecausing injury': ['GB',
#   'Tarmac Defect'],
#  'claimant while cycling fell due to broken tarmac on the surface ofroad sustaining body injury': ['GB',
#   'Tarmac Defect'],
#  'claimant had an allergic reaction upon using the product': ['PA',
#   'Soap, detergent, cleaning compound'],
#  'two employees were in the process of moving a pallet that had a tbar underneath it the tbar fell and hit a member in the head': ['GB',
#   'Employee'],
#  'insured vehicle stationary at traffic light when a road works signwas blown onto side of insured vehicle': ['AP',
#   'Misc - Object Hit Vehicle'],
#  'claimant suffer bodily injury due to delay in receiving part of boiler': ['GB',
#   'Boiler, pressure vessel, etc.'],
#  'multiple collision phv stationary shunted into rear of tpv': ['AD',
#   'Multiple Vehicle Collision'],
#  'the resident in apt b was cooking when the stove caught fire no injuries were reported': ['RB',
#   'Grease Fires - Kitchen'],
#  'customer stated they slipped on liquid that was on floor': ['GB',
#   'Soap, detergent, cleaning compound'],
#  'subrogated claim alleged improperly closed paint can spilled in the trunk': ['GD',
#   'Container - Packaging Etc'],
#  'claimant during the course of employment washing his lorry using soap provided when his hand suddenly started to burn suffered bodily injury': ['EL',
#   'Soap, detergent, cleaning compound'],
#  'claimant was crossing the road when her foot went into a broken drain cover claimant sustain injury': ['GB',
#   'Fall - hole/drain cover - defect/missing'],
#  'the claimant was asked to tap a new ale barrel and when he stood up he hit his head on the ceiling causing injury': ['EL',
#   'Ceiling Collapse'],
#  'canada cartage delivery driver cut his left leg above the ankle ona piece of rebar that blended in into the asphalt it was a staged order to go out on a pallet rebar was not flagged': ['GB',
#   'Sharp Object'],
#  'customer purchased paint in store and when they arrived home it had spilled in their trunk causing damage': ['GD',
#   'Container - Packaging Etc'],
#  'roller shutters damaged by vehicle': ['RB', 'VEHICLE'],
#  'an empty box fell off a flatbed being pushed by an ee and struck the member in the head': ['GB',
#   'Employee'],
#  'the driver has backed into the wall on his right frame damage to the window': ['AD',
#   'Employee'],
#  'laundry detergent spill on floor': ['GB',
#   'Soap, detergent, cleaning compound'],
#  'kitchen fire': ['RB', 'Grease Fires - Kitchen'],
#  'claimant suffered property damage due to floor flooded': ['GD',
#   'Leak/Flood - Defective Workmanship'],
#  'claimant suffered injuries due to ceiling collapsed on her': ['GB',
#   'Ceiling Collapse'],
#  'the latch came loose on the trailer and the door came open some packages were lost he lost less that a of his load': ['AD',
#   'Trailer - Door/Seal'],
#  'member claims that tailgate was bent when he had a couch loaded into his truck': ['GD',
#   'Misc - Object Hit Vehicle'],
#  'insured was moving into the left hand lane and a motorcycilst has crashed into them caused damage': ['AD',
#   'Insured Turned Against TP Path'],
#  'claimant vehicle drove over speed bump causing damaged to claimantvehicle': ['GD',
#   'Speed bump'],
#  'jay furbay who is a member of the resort checked out a rental bikeand went along th road when he fell off bike': ['PM',
#   'Bicycle'],
#  'claimant while cycling the gears failed which jammed the wheel causing the claimant to fall off': ['EL',
#   'Bicycle'],
#  'temp emp sustained a laceration to his right lower leg requiring stitches due to being struck by the porcelain toilet lid that ricocheted out of the hopper due to him throwing it into the hopper': ['AB',
#   'Contract Hauler Accident/Temp Employee'],
#  'claimant alleges while in the stall she injured the right little finger on the door': ['GB',
#   'Trailer - Door/Seal'],
#  'claimant suffered property damage due to leaking pipe and hole in ceiling water poured out': ['GD',
#   'Defective Pipework'],
#  'clamant suffered property damage due to defective workmanship caused water damage': ['GD',
#   'Leak/Flood - Defective Workmanship'],
#  'property owner stated the dumpster she uses to dispose of grease in had its lid blow off today and it struck the side of her vehicle which was parked next to it in the parking lot': ['GD',
#   'Natural Hazard-Non Vegetation'],
#  'member purchased bike and suffered a dangerous incident being knocked out temporarily due to incorrect installation of bike': ['GB',
#   'Bicycle'],
#  'exact cause of damage unknown caused by sub contractor when carrying out works in property claimant suffered property damage': ['GD',
#   'EXACT CAUSE OF DAMAGE UNKNOWN'],
#  'claimant fall over a defective kerb stone causing bodily injury': ['GB',
#   'Trip - kerb stone'],
#  'claimant suffer property damage due to leak': ['GD',
#   'Leak/Flood - Defective Materials'],
#  'while on duty and riding a department issued bicycle the claimant is left foot slipped off of the pedal and she twisted her left ankle when she planted her foot on the ground': ['NS',
#   'Bicycle'],
#  'claimant suffered property damage due to water dripping from the faulty tank': ['GD',
#   'Leak/Flood - Defective Materials'],
#  'claimant is alleging he injured knee on sushi display case': ['PA',
#   'Office or Restaurant Furniture'],
#  'at about am this morning i was unloading a shipment from bessier city on a hot shot trailer flat': ['GD',
#   'Aircraft'],
#  'claimant drove over defective tarmac caused vehicle damage': ['GD',
#   'Tarmac Defect'],
#  'claimant s foot slipped on a slippery substance on the floor causing damaged': ['OM',
#   'DEFECTIVE FLOOR'],
#  'fall in handicapped stallpossible seizure as reported by family fall as guest transferred from toliet to wheelchair': ['GB',
#   'Natural Hazard-Non Vegetation'],
#  'ram raid causing structural damage to wall': ['RB', 'VEHICLE'],
#  'claimant stepped in drain cover suffered injury': ['EL',
#   'Fall - hole/drain cover - defect/missing'],
#  'claimant tripped falling forward over raised drain cover and sunken road surface causing injury': ['GB',
#   'Fall - hole/drain cover - defect/missing'],
#  'claimant suffered property damage as jacket caught in sharp cornercausing it to ripped off': ['GD',
#   'Sharp Object'],
#  'guest left the henry and was walking on sidewalk and stepped into tree opening fell and was injured injury not specified but guestwent to the emergency room to be treated no cameras that belong to the building capture the area where incident happened howeverthe henry has a camera that points at the exact location and may have captured the incident this happened on public property': ['GB',
#   'Natural Hazard-Vegetation'],
#  'zeon chemicals three manufacturing facilities experienced damages resulting from the extended freeze period that occurred in decembe': ['BM',
#   'Boiler, pressure vessel, etc.'],
#  'child outside smashed saloon window on nearside bus reg bxpcf': ['AB',
#   'Sharp Object'],
#  'customer picked up a litre of ceiling paint from the paint desk and it fell on him paint associate checked the can over all seemed to be good customer came back to the paint department withpaint on his jacket he said it came from the container': ['GD',
#   'Container - Packaging Etc'],
#  'claimant suffer with epilepsy and this leak and situation have affected claimant health due to leakage of ceiling': ['GB',
#   'Leak/Flood - Defective Materials'],
#  'damage to car involving pipe work that left in the drive caused property damage': ['GD',
#   'Other'],
#  'customer claims that there was something sharp in the soap she purchased and scratched her arm': ['PA',
#   'Sharp Object'],
#  'driver of forklift crashed into wall': ['RB', 'VEHICLE'],
#  'paint can spilled on the customer is wallet and the bottom portion of the jacket': ['GD',
#   'Container - Packaging Etc'],
#  'engr thomas skowronski while on the scene of a fire was attempting to relocate large diameter hose line injured his left arm ambo transported him to little company of mary hospital': ['NS',
#   'Hose'],
#  'claimant suffered property damage due to flooding caused water damage': ['GD',
#   'Defective Pipework'],
#  'damage to claimant is vehicle due to defect on the highway': ['GD',
#   'Road Conditions/Weather'],
#  'claimant while walking slipped due to paving stone and fell down causign personal injuries': ['GB',
#   'Trip - kerb stone'],
#  'claimant slipped over black ice causes bodily injuries': ['EL',
#   'Frost/Ice/Snow'],
#  'customer claims she was walking from her car towards our store when she got to our sidewalk she slipped and landed on her hands and knees': ['GB',
#   'Soap, detergent, cleaning compound'],
#  'claimant tripped and fell over eroded tarmac causing bodily injury': ['GB',
#   'Tarmac Defect'],
#  'customer claims associate spoke aggressively and made race based comments told the customer in this country i am considered as blackwhich projected even more prejudice towards the customer by projecting some of allen is own frustration': ['PI',
#   'Employee'],
#  'claimant suffered injury due to the same road': ['GB',
#   'Road Conditions/Weather'],
#  'while towing insured cause damage to third party vehicle causing vehicle damage': ['AD',
#   'Insured Turned Against TP Path'],
#  'insured vehicle turned across path hit third party causing bodily injury': ['AB',
#   'Insured Turned Against TP Path'],
#  'ee opened garage door to take the member is car out but it came back down ripping off antenna as he backed out': ['GK',
#   'Employee'],
#  'cts hired third party carrier landstar pulling rv driver fell asleep in transit through bc canada and lost control of tractor': ['AP',
#   'Insured Lost Control'],
#  'guest claims the team member ran into the suburban door with the fork lift mask': ['GD',
#   'Machine - point of operation'],
#  'a child approximately year old girl tried to dispense hand sanitizer when it squirted in her eye parents took her to the washroom and washed her eye with water': ['GB',
#   'Soap, detergent, cleaning compound'],
#  'miguel munoz stepped into a hole while visiting his brother in laws grave in which it caused him to fall': ['GB',
#   'Natural Hazard-Vegetation'],
#  'claimant walking the path was covered with moss and twigs causing him to slip and fall sustaining injuries': ['GB',
#   'Other'],
#  'claimant alleges while laying down fries at the fryers she was burned by the grease the ee sustained a first degree burn on her right hand': ['NS',
#   'Grease Fires - Kitchen'],
#  'clmnt minor got up from bed to retrieve water from fridge when returning to bed she hit table topple over striking left foot': ['GB',
#   'Office or Restaurant Furniture'],
#  'clmt alleges to have become ill after consuming raw oven roasted chicken alleges chicken was not cooked thoroughly and caused foodpoisoning': ['GB',
#   'Infectious, parasitic agents, NOC - Liab.'],
#  'approx pm gail was stuck on elevator and did not have access to the fire speaker during her incident banged on the elevat': ['GB',
#   'Machine - point of operation'],
#  'insured vehicle turned across path of third party causing damage and loss': ['AU',
#   'Insured Turned Against TP Path'],
#  'subcontractor driver neglected to secure the kingpin causing the tanker to fall on the ground this resulted in minor damage to thetruck no injuries': ['AD',
#   'Contract Hauler Accident/Temp Employee'],
#  'record only fire sprinklers in the kitchen of apt went off due to grease fire causing flooding into two other units in the sam': ['GD',
#   'Grease Fires - Kitchen'],
#  'claimant trip on a broken bit of tarmac claimant sustain injury': ['GB',
#   'Tarmac Defect'],
#  'several drops of blood were found at the end of aisle by an associate no customers were near by and nothing had been reported by a customer e was called for clean up instructions referencenumber': ['GB',
#   'EXACT CAUSE OF DAMAGE UNKNOWN'],
#  'ceiling came sown causes property damage': ['GD',
#   'Leak/Flood - Defective Workmanship'],
#  'pipe failed causing a sinkhole': ['RB', 'Sink Hole'],
#  'impact damage by vehicle to building': ['RB', 'VEHICLE'],
#  'tsp driver was on hwy going nb when the rear trailer door cameopen several packages were lost': ['AD',
#   'Trailer - Door/Seal'],
#  'claimant suffered vehicle damage due to defective tarmac': ['GD',
#   'Tarmac Defect'],
#  'clamant fell from ladder due to defective floor causing injury': ['GB',
#   'DEFECTIVE FLOOR'],
#  'ee states making deliverypulled out trailer rampmissed ramp hooksmashed r thumb with rampcaused paincutbleedingswelling': ['NS',
#   'Trailer - Door/Seal'],
#  'the temporary employee was in the process of collections at a residential site and while throwing a piece of trash into the rear loader of the waste management equipment the temporary employee was struck by the piece of trashthis caused a lacerationon his arm': ['AB',
#   'Contract Hauler Accident/Temp Employee'],
#  'temp ee was servicing customer location on street when struck over the head with a trash can while handling it he sustained a contusion': ['AB',
#   'Contract Hauler Accident/Temp Employee'],
#  'claimant vehicle was damaged due to road conditions': ['GD',
#   'Road Conditions/Weather'],
#  'while the broaster was being used in the kitchen it caught on fire there were no injuries reported': ['RB',
#   'Grease Fires - Kitchen'],
#  'roller shutters damaged by veh': ['RB', 'VEHICLE'],
#  'iv driver was on a test driver in a customers vehicle iv was struck on the ps of ov ov driver w': ['GK',
#   'Aircraft'],
#  'member alleges an employee touched his wife': ['GB', 'Employee'],
#  'insured vehicle collided multiple parked vehicle causing vehicle damage': ['AD',
#   'Multiple Vehicle Collision'],
#  'claimant slipped on defective floor causing bodily injury': ['GB',
#   'DEFECTIVE FLOOR'],
#  'one gallon of behr paint burst in customers trunk and seat due to failure of paint cans lid': ['GD',
#   'Container - Packaging Etc'],
# ...
#   'Contract Hauler Accident/Temp Employee'],
#  'the iv driver was driving down a street and while attempting to changes lanes the ds rear end of th': ['GK',
#   'Aircraft'],
#  'claimant trip due to kerb causing bodily injury': ['GB',
#   'Trip - kerb stone'],
#  'impact damage to roller shutters by tp': ['RB', 'VEHICLE'],
#  'insured turned across path of third party causing damaged': ['AD',
#   'Insured Turned Against TP Path'],
#  'veh was heading to the intersection to a stop sign on ocean blvd higel st in sarasota fl there was a vehicle stopped in front of veh and a vehicle behind veh a woman on a bicycle came from the left on higel street the woman on the bicycle made a right from higel street onto ocean blvd and crossed the street and made contact with veh causing damage to veh vehmary kay inc': ['AN',
#   'Bicycle'],
#  'insured has turned into a road collided into third party vehiclecausing damage': ['AD',
#   'Insured Turned Against TP Path'],
#  'claimant while walking slipped and fall due to metal poles sticking up on the tarmac causing injury': ['GB',
#   'Tarmac Defect'],
#  'passenger fell dwn due to speed bump bus reg bxlje': ['AB', 'Speed bump'],
#  'insured was opening the door to the trailer when it struck his hand sustained fracture to left middle finger': ['NS',
#   'Trailer - Door/Seal'],
#  'the iv driver was at gas station when he drove off without takingthe hose outthis caused the hose to break off the iv incurred nodamage there were no injuries reported': ['AD',
#   'Hose'],
#  'liam was pushing trolleys and was turning in road when members carclipped liams foot': ['EL',
#   'VEHICLE'],
#  'bin hit claimants vehicle causing vehicle damage': ['GD',
#   'Misc - Object Hit Vehicle'],
#  'claimant suffered vehicle damage due to hardcore from road struck windscreen': ['GD',
#   'Misc - Object Hit Vehicle'],
#  'insured hit third party vehicle while turning right causing damaged': ['AD',
#   'Insured Turned Against TP Path'],
#  'unknown customer entered the store at assisted checkout screaming and asking for someone to call an ambulance the unknown customer said there was pain in his foot an ambulance was called and paramedics took him away': ['GB',
#   'EXACT CAUSE OF DAMAGE UNKNOWN'],
#  'claimant while driving hit the tram tracks his bike slid from under him and he fell to the ground': ['GB',
#   'Bicycle'],
#  'turning in county lane caught bumper on verge causing damaged': ['AP',
#   'Insured Turned Against TP Path'],
#  'small pd the temporary ee was servicing while operating the iv ata residential site when the temporary ee threw out an item that was not designated for the trash pile he was picking up with the iv there is no damage to the iv no injuries sustained': ['AD',
#   'Contract Hauler Accident/Temp Employee'],
#  'customer was shopping for plumbing parts in aisle a met associate walked through pulling a pallet and hit him on his ankles with the wooden pallet customer was offered first aid immediately but declined and went home called at approx pm that': ['GB',
#   'Employee'],
#  'the cust was at pump pumping gas in the vehicle but the hose hada hole and gas sprayed allover the cust is pants and shoes': ['GD',
#   'Hose'],
#  'claimant suffered property damaged due to a stone was discharged from the rear of the gritter which smashed my windscreen': ['GD',
#   'Misc - Object Hit Vehicle'],
#  'insured collided with third party vehicle causing vehicle damage': ['AD',
#   'Insured Turned Against TP Path'],
#  'claimant suffered from injuries': ['GB', 'Other'],
#  'customer came in and said that ice fell on her face and landed on her glass this happened by the entrance and falling ice from the roof she said for now she is okay': ['GB',
#   'Frost/Ice/Snow'],
#  'hail storm damaged vehicle while in clients possession': ['AP',
#   'Natural Hazard-Vegetation'],
#  'kneeling to clean and inspect the forward swashplate i felt a pop in my right knee': ['NS',
#   'Aircraft'],
#  'member fell from a chair': ['NS', 'Office or Restaurant Furniture'],
#  'slipped on detergent': ['GB', 'Soap, detergent, cleaning compound'],
#  'caller state driver lost control on west bound run onto a guardrail': ['AD',
#   'Insured Lost Control'],
#  'iv was tunring around in a parking lot and hit a sink hole causingdamage to multiple parts of iv': ['AP',
#   'Sink Hole'],
#  'claimant while walking slipped due to tarmac defect and fell down causing personal injuries': ['GB',
#   'Tarmac Defect'],
#  'debris from the window of insured vehicle hit a third party vehicle': ['AD',
#   'Misc - Object Hit Vehicle'],
#  'mbr slipped and fell under the awning of the wh alleged presence of an unsalted icy patch': ['GB',
#   'Frost/Ice/Snow'],
#  'due to stop pedestrians when work is being done on the railings caught the wind which caught my handlebars and threw me off bicycle': ['GB',
#   'Bicycle'],
#  'claimant was walking his dog at the above location when he steppedon a manhole cover and fell causing injury': ['GB',
#   'Fall - hole/drain cover - defect/missing'],
#  'claimant suffered property damage due to boiler broke': ['GD',
#   'Boiler, pressure vessel, etc.'],
#  'alleged damage to boiler due to water ingress': ['GD', 'Other'],
#  'claimant suffered injury due to collapse of ceiling': ['GB',
#   'Ceiling Collapse'],
#  'passenger sat down he saw sharp object which was needle in seats bus reg bxacy': ['AB',
#   'Sharp Object'],
#  'a customer was pumping gas on pump and stepped over the host andtrip the customer struck her face on the floor causing a scratchon her nose': ['GB',
#   'Hose'],
#  'drunk driver struck school gates': ['RB', 'VEHICLE'],
#  'insured was shutting trailer in the snow and it went down too fastcausing insured to fall sprain to both knees and pulled hammy': ['NS',
#   'Trailer - Door/Seal'],
#  'mbr states asked for help from a carts clerk to load up a steel shelve into van mbr claims clerks hand slipped causing scratches': ['GD',
#   'Misc - Object Hit Vehicle'],
#  'the driver stated i came to a stop sign a way stop sign i couldn not see anyone to my right vie': ['AD',
#   'Aircraft'],
#  'claimant suffer property damage due to leakage from defective material': ['GD',
#   'Leak/Flood - Defective Materials'],
#  'guest said she had to move from room around due to leak in bathroom from room above and toilet not flushing she said s': ['GB',
#   'Infectious, parasitic agents, NOC - Liab.'],
#  'claimant was walking and fall down due to drain cover was up so far from the ground causing bodily injury': ['GB',
#   'Fall - hole/drain cover - defect/missing'],
#  'insured vehicle has turned across the path of third party vehicle causing vehicle damage': ['AD',
#   'Insured Turned Against TP Path'],
#  'claimant suffer property damage causing burst pipe': ['GD',
#   'Leak/Flood - Defective Materials'],
#  'over pressurization of condenser water pipe cause a gasket to blowout': ['GD',
#   'Boiler, pressure vessel, etc.'],
#  'resident contacted fire and rescue invicta security came to the scene and reported an incident report the unitwas assessed by ourservice manager our contractor novonty is coming to fix all repairs': ['RB',
#   'Grease Fires - Kitchen'],
#  'insured vehicle has been damaged circumstances unknown': ['AP',
#   'EXACT CAUSE OF DAMAGE UNKNOWN'],
#  'claimant while walking tripped and fell due to uneven surface and sustained injuries': ['GB',
#   'Tarmac Defect'],
#  'the claimant suffered injuries due to the roof of the classroom fell on top of her': ['EL',
#   'Ceiling Collapse'],
#  'member aggravated left ankle during hr bicycle training course at mccormack place member went to resurrection hospital on apr member has sprained left ankle currently on crutches': ['NS',
#   'Bicycle'],
#  'guest posted on instagram that we got her sick with togo food and that went to the er our guest relations team reached out and asked for additional information the restaurant sent email requesting additional information so we can resolve and have not had a reply': ['PA',
#   'Infectious, parasitic agents, NOC - Liab.'],
#  'insured vehicle hit third party vehicle while turning caused damage to vehicle': ['AD',
#   'Insured Turned Against TP Path'],
#  'claimant exposed to decease while working caused to death': ['GB',
#   'Asbestos'],
#  'claimant suffered property damage due to pipe had burst top floor flat causing water damage': ['GD',
#   'Defective Pipework'],
#  'claimant suffered injury due to ceiling collapse': ['GB',
#   'Ceiling Collapse'],
#  'claimant tripped due to raised bricks sticking causing bodily injury': ['GB',
#   'Trip - kerb stone'],
#  'claimant coat ripped due to sharp object': ['GD', 'Sharp Object'],
#  'customer was driving home with g paint cane and got spilled in his truck ford f': ['GD',
#   'Container - Packaging Etc'],
#  'insured vehicle nearside hit bush causing vehicle damage to insured vehicle': ['AP',
#   'Misc - Object Hit Vehicle'],
#  'claimant was cycling he fell due to defect in road caused injury': ['GB',
#   'Road Conditions/Weather'],
#  'pulled up on door and muscle popped': ['NS', 'Trailer - Door/Seal'],
#  'vehicle damage caused by a pothole': ['GD', 'Sink Hole'],
#  'a technician was driving a customer is vehicle and when pulling forward they ran into the side of a': ['GK',
#   'Aircraft'],
#  'the guest called in and mentioned that their house is infested with bed bugs and they believe it came from room that they were staying in there were no reported injuries': ['GD',
#   'Infectious, parasitic agents, NOC - Liab.'],
#  'went into the bar to purchase a few gift cards but wanted to sit down she tried to climb the highchair at the bar but lost her balance and fell backwards she hit her head on the floor and started bleeding i was alerted that it happened and called the fire department they came and looked at her head and noticed that she needed stiches': ['GB',
#   'Office or Restaurant Furniture'],
#  'event sp ran over water hoses aa broke them no injury no tow no police': ['AD',
#   'Hose'],
#  'truck and trailer to hit the central reservation damage all down the os step mudguard steering out of alignment trailer back': ['AD',
#   'Insured Lost Control'],
#  'a porter was driving the iv and drove too close to the wall causing the veh to scrape against it t': ['GK',
#   'Aircraft'],
#  'debris has fallen from clients vehicle has caused damage to claimants vehicle': ['AD',
#   'Misc - Object Hit Vehicle'],
#  'claimant suffered vehicle damage due to defective speed bump': ['GD',
#   'Speed bump'],
#  'on may th city of davis experience extremely high winds over the night hitting mph we had a tree branch split and land on top of a resident is vehicle a tree branch was split over the night of may th by high winds the branch of the tree landedon top of a resident is vehicle no windows were broken and the damage did seem minimal from the eye the resident was in the bay area and returned home at pm today may th i spoke with': ['GD',
#   'Natural Hazard-Vegetation'],
#  'claimant suffered property damage due to over flowing sink': ['GD',
#   'Sink Hole'],
#  'claimant suffered property damage due to leakage of floor': ['GD',
#   'Leak/Flood - Defective Workmanship'],
#  'clmt claims that she had an allergic reaction to the feather pillows in the guest alledging she sought medical treatment': ['GB',
#   'Infectious, parasitic agents, NOC - Liab.'],
#  'shutter doors ram raided': ['RB', 'VEHICLE'],
#  'claimant stepped on tarmac defect causing injury': ['GB', 'Tarmac Defect'],
#  'clamant drove over bad conditioned road causing vehicle damage': ['GD',
#   'Road Conditions/Weather'],
#  'claimant slipped and fell leaving premises not a mbr but a ee working at the cell phone kiosk': ['GB',
#   'Frost/Ice/Snow'],
#  'box from insured vehicle hit third party vehicle causing third party vehicle damage': ['AD',
#   'Misc - Object Hit Vehicle'],
#  'a magnolia driver reported that she was parked along the shipping side trying to close the door to her trailer when she slipped causing the trailer door to strike her left elbow her left elbow was red and bruised she refused medical attention': ['GB',
#   'Trailer - Door/Seal'],
#  'claimant suffered property damage due to tree roots from the abovevegetation': ['GD',
#   'Natural Hazard-Non Vegetation'],
#  'driver had cut his finger on wiper blade at garage doing his walk bus reg bxddz tp reg unknown': ['EL',
#   'Sharp Object'],
#  'customer claiming she got food poisoning after buying cookies fromthe clearance rack': ['GB',
#   'Infectious, parasitic agents, NOC - Liab.'],
#  'lrsquoaccident de la route avec bris mais sans blessure srsquoest produit sur lrsquoautoroute est pregraves de staugustin vers am vendredi le feacutevrier normand latulippe conduisait dans un gros brouillard de neige la visibiliteacute eacutetant reacuteduite et la chausseacutee tregraves glissante normand nrsquoa pas reacuteussi agrave srsquoimmobiliser agrave temps pour eacuteviter le veacutehicule devan': ['AD',
#   'Road Conditions/Weather'],
#  'claimant suffered injury due to sunken road surface': ['GB',
#   'Road Conditions/Weather'],
#  'resident started cooking on stoveoven and then left the unit theitems that were left unattended on the stove top started a small fire with heavy smoke smoke damaged is throughout unit': ['RB',
#   'Grease Fires - Kitchen'],
#  'resident stated that upon washing clothes he noticed the markings and bleaching on the shirts and some sheets after running the was': ['GD',
#   'Soap, detergent, cleaning compound'],
#  'insured was getting out of his truck when he stepped in a hole andheard a pop in his left knee': ['NS',
#   'Sink Hole'],
#  'claimant slipped over ice causes injuries': ['EL', 'Frost/Ice/Snow'],
#  'insured stepped in sink hole that was full of water looked like aneven surface complains of neck and back pain sees a chiro': ['NS',
#   'Sink Hole'],
#  'customer was in the store between the hours of am am he hadsome product loaded in his truck but nothing contributed to the damage he discovered when he arrived home since it was his only stop he thinks something else hit and damaged his truck': ['GD',
#   'EXACT CAUSE OF DAMAGE UNKNOWN'],
#  'insured slipped on ice and pulled the door closed on his right hand when he fell sustained fracture to middle and ring finger onright hand': ['NS',
#   'Trailer - Door/Seal'],
#  'claimant tripped over a speed bump causing injury': ['GB', 'Speed bump'],
#  'the customer walked to the hyper freeze machine in the chill zone area and began filling his cup suddenly he fell face first into the machine got up but then fell down two more times it was evident that he was suffering from heat exhaustion': ['GB',
#   'Machine - point of operation'],
#  'claimant suffered property damage due to broke pipe in a drain': ['GD',
#   'Defective Pipework'],
#  'the customer was standing the asile shoppoing the associate helping another customer accsidently droped the satin gal on thefloor and it splashed around including the customer clothes and foot wear please note the customer was not hurt no injury': ['GD',
#   'Container - Packaging Etc'],
#  'claimant suffered dampness causing unwell or breathing problem': ['GB',
#   'Leak/Flood - Defective Workmanship'],
#  'claimant tripped due to a dip between a kerb stone and a flag stone on the footpath causing injury': ['GB',
#   'Trip - kerb stone'],
#  'member injured his back while changing hose in quarters and then transported to hospital for evaluation by a': ['NS',
#   'Hose'],
#  'claimant fall over an edging kerb causing bodily injury': ['GB',
#   'Trip - kerb stone'],
#  'member was subject of hit run mva at gas station member suffered a fractured police report made cctv saved': ['GB',
#   'VEHICLE'],
#  'left index finger injury': ['NS', 'Office or Restaurant Furniture'],
#  'customer is claiming the oven roasted chicken was not cooked thoroughly and caused food poisoning': ['GB',
#   'Infectious, parasitic agents, NOC - Liab.'],
#  'claimant suffered injuries due to carbon monoxide exposure': ['GB',
#   'Boiler, pressure vessel, etc.'],
#  'on dec th around pm a custmer claimed that he was threatened by associate andrew funk there was no known injury to the customer reach out to store for more details': ['PI',
#   'Employee']}

# %%
fewer_class_dictionary_as[fewer_data_as['Claim Description'].iloc[0]]
# Out:
# ['GD', 'Leak/Flood - Defective Materials']

# %%
data_as_step_2 = data_step_2.copy()

def convert_class(feature):
    if feature in medium_classes_as:
        return 'med'
    else:
        return feature
    
data_as_step_2['Accident Source'] = data_as_step_2['Accident Source'].apply(convert_class)

# %%
data_as_step_2['Accident Source'].value_counts()
# Out:
# Alleged Negligent Act                    20254
# Sideswipe or lane change                 15414
# Struck animal or object                   7720
# Struck vehicle in rear                    7400
# Not Otherwise Classified                  7377
#                                          ...
# Insured vehicle causes other accident      103
# Excavation, trench, tunnel                 102
# Alleged Discrimination                     101
# Door - Office                              101
# Malicious Mischief                         101
# Name: Accident Source, Length: 150, dtype: int64

# %% [markdown]
# #### Step 3 : Develop a model on given classes :

# %% [markdown]
# ##### vectorization of feature

# %%
# create features and class label

X = data_as_step_2['Claim Description']

y = data_as_step_2['Accident Source']

# %%
# split the dataset



X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20)

# %%
# convert data into vector form

count_vector_as_step_1 = CountVectorizer()

X_train = count_vector_as_step_1.fit_transform(X_train)
X_test = count_vector_as_step_1.transform(X_test)

# %%
# # usning tfidf vectorizer

# from sklearn.feature_extraction.text import TfidfVectorizer

# tfidf_vectorizer = TfidfVectorizer(use_idf=True)
# X_train_vectors_tfidf = tfidf_vectorizer.fit_transform(X_train) #tfidf runs on non-tokenized sentences unlike word2vec
# # Only transform x_test (not fit and transform)
# X_val_vectors_tfidf = tfidf_vectorizer.transform(X_test)

# %%
X_train.shape
# Out:
# (131192, 77503)

# %% [markdown]
# ##### Model 1 - naive bayes

# %%
# train
naive_bayes = MultinomialNB()
naive_bayes.fit(X_train, y_train)
print("Model trained")

# save model
path = "results/naive_bayes_as_step_1.pickle"
pickle.dump(naive_bayes, open(path, "wb"))
print("Model saved to", path)

# predict
y_pred = naive_bayes.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print('Accuracy for naive bayes :',np.round(accuracy,2))

print("*"*100)

target_names = naive_bayes.classes_
print(classification_report(y_test, y_pred, target_names=target_names))
print('*'*100)
# Out:
# Model trained
# Model saved to results/naive_bayes_as_step_1.pickle
# Accuracy for naive bayes : 0.35
# ****************************************************************************************************
#                                             precision    recall  f1-score   support
#
#     Accidental disposal of property/object       0.00      0.00      0.00        85
#                    Administrative Decision       0.00      0.00      0.00        23
#                     Alleged Discrimination       0.00      0.00      0.00        17
#                           Alleged Incident       0.00      0.00      0.00        19
#       Alleged Misconduct - Personal Injury       0.00      0.00      0.00        21
#                      Alleged Negligent Act       0.26      0.83      0.40      4102
#                    Alleged concrete defect       0.00      0.00      0.00        30
#          Alleged contamination or spoilage       0.54      0.48      0.50       410
#       Alleged damage to property of others       0.79      0.14      0.23       386
#                Alleged design flaw, defect       0.79      0.09      0.17       353
#          Alleged foreign object in product       0.64      0.63      0.63       484
#   Alleged improper maintenance - municipal       0.00      0.00      0.00        69
#       Alleged improper maintenance - other       0.33      0.16      0.21       961
#     Alleged improper maintenance - schools       0.00      0.00      0.00        16
#    Alleged installation by vendor/retailer       0.00      0.00      0.00        41
#                   Alleged lack of security       0.00      0.00      0.00        38
#        Alleged lack of supervision - other       0.00      0.00      0.00        48
#      Alleged lack of supervision - schools       0.40      0.02      0.04        92
#       Alleged mechanical defect of failure       0.00      0.00      0.00        40
#                  Alleged product loss, NOC       1.00      0.27      0.43        99
# Alleged service or maint.- vendor/retailer       1.00      0.01      0.02       257
# Alleged service or maintenance by customer       0.00      0.00      0.00        28
#                          Allergic Reaction       0.00      0.00      0.00        90
#                             Animal, Insect       0.57      0.03      0.06       137
#                                    Assault       0.00      0.00      0.00        85
#                       Assault and/or abuse       0.00      0.00      0.00        50
#                Assault during apprehension       0.00      0.00      0.00        29
#              Backed into vehicle or object       0.47      0.43      0.45      1228
#                                   Bathroom       0.00      0.00      0.00        48
#                     Box, barrel, container       0.00      0.00      0.00        40
#                     Building services, NOC       0.00      0.00      0.00        32
#        Burglary, Robbery, Theft - Property       0.00      0.00      0.00        62
#                   Burglary, robbery, theft       0.00      0.00      0.00       164
#                                   Car Wash       1.00      0.02      0.05        84
#                                   Car stop       0.00      0.00      0.00        27
#                                       Cart       0.80      0.21      0.34       421
#                                  Collision       0.00      0.00      0.00        50
#                  Collision on a Roundabout       0.00      0.00      0.00        41
#                         DEFECTIVE PAVEMENT       1.00      0.01      0.03        68
#                          DEFECTIVE PRODUCT       0.00      0.00      0.00        42
#                      Damage to landscaping       0.69      0.16      0.26       337
#                                    Display       0.00      0.00      0.00        56
#                              Door - Office       0.00      0.00      0.00        13
# Elevator,escalator,manlift,moving sidewalk       0.00      0.00      0.00        44
#                         Elevator/Escalator       0.00      0.00      0.00        23
#           Entering or leaving traffic flow       0.00      0.00      0.00       108
#                      Equipment Malfunction       0.00      0.00      0.00        65
#                 Excavation, trench, tunnel       0.00      0.00      0.00        29
#                        Extreme temperature       0.00      0.00      0.00        32
#                             Falling Object       0.00      0.00      0.00       112
#                                Fire - Auto       0.00      0.00      0.00        89
#                            Fire - Property       0.00      0.00      0.00        40
#                               Food Product       0.53      0.18      0.26       336
#                      Foreign object thrown       0.00      0.00      0.00        58
#   Freezing of Plumbing, Heating, AC System       0.55      0.11      0.18       102
#                         Furniture, fixture       0.00      0.00      0.00        69
#                             Gasoline spill       0.00      0.00      0.00        47
#                                Gate, fence       0.00      0.00      0.00        58
#                        Glass, ceramic, NOC       1.00      0.02      0.04        50
#                               Ground/floor       0.00      0.00      0.00       388
#                                       Hail       0.00      0.00      0.00        45
#                          Head-on collision       0.00      0.00      0.00        88
#                              Health Hazard       1.00      0.10      0.18        50
#                 Hit Post/Barrier/Gate/Pole       0.00      0.00      0.00        46
#                    Hit Third Party In Rear       0.00      0.00      0.00        25
#                             Hit Wall/Fence       0.00      0.00      0.00        20
#                 Hit in Rear by Third Party       0.00      0.00      0.00        23
#                          Human Action, NOC       0.54      0.17      0.25       368
#                Ice, Snow, Sleet - Property       0.00      0.00      0.00        29
#                    Ice, Snow, Sleet - W.C.       0.00      0.00      0.00        20
#                                  Ice/water       0.00      0.00      0.00       276
#   Injured while entering/alighting vehicle       1.00      0.01      0.03        68
#                      Insured Changed Lanes       0.00      0.00      0.00        19
#                      Insured Hit Parked TP       0.00      0.00      0.00        48
#                   Insured Reversing Hit TP       0.00      0.00      0.00        39
#      Insured vehicle causes other accident       0.00      0.00      0.00        12
#                      Intersection accident       0.63      0.17      0.27       898
#     Jacknife, rollover, overturned vehicle       0.50      0.01      0.02        85
#                         Malicious Mischief       0.00      0.00      0.00        17
#                                Merchandise       0.00      0.00      0.00        82
#                      Merchandises on Floor       0.00      0.00      0.00        55
#                            Metal item, NOC       0.00      0.00      0.00        33
#                                Mold/mildew       0.00      0.00      0.00        33
#     Non Liability Cases - Premises Medical       1.00      0.08      0.15        98
#                       Non-contact accident       0.00      0.00      0.00        95
#                   Not Otherwise Classified       0.33      0.11      0.16      1501
#         Object fall - loading or unloading       0.00      0.00      0.00        53
#                            Object on floor       0.00      0.00      0.00       151
#                              Oil or grease       0.00      0.00      0.00        47
#                      Other - comprehensive       0.50      0.00      0.01       321
#                 Other vehicle turning left       0.00      0.00      0.00        75
#                Other vehicle turning right       0.00      0.00      0.00        40
#                    Our vehicle backed into       0.00      0.00      0.00       204
#     Our vehicle struck by object or animal       0.00      0.00      0.00       143
#      Our vehicle struck by runaway vehicle       0.00      0.00      0.00        59
#                 Our vehicle struck in rear       0.65      0.11      0.18       771
#            Our vehicle struck while parked       0.00      0.00      0.00       261
#                   Our vehicle turning left       0.00      0.00      0.00       204
#                  Our vehicle turning right       0.00      0.00      0.00       125
#                                     Pallet       0.00      0.00      0.00        39
#                       Pallet Jack (manual)       0.00      0.00      0.00        21
#                      Parking lot, driveway       0.00      0.00      0.00       261
#                    Particle/Foreign Object       0.00      0.00      0.00        36
#  Plumbing,Heating,AC,Discharge,Overflowing       0.48      0.39      0.43       197
#                                    Pothole       0.00      0.00      0.00        69
#                                       Rain       0.00      0.00      0.00        35
#                            Ran off roadway       0.00      0.00      0.00        82
#                    Road debris/road hazard       0.64      0.25      0.36       312
#                            Runaway vehicle       0.00      0.00      0.00        32
#                              Scrap, debris       0.00      0.00      0.00        27
# Sharps(Needles,Razors,Scissors,Knife,etc.)       0.00      0.00      0.00        30
#                   Sideswipe or lane change       0.33      0.86      0.48      3075
#   Sprinkler Leakage - Pipe or Head Failure       0.00      0.00      0.00        39
#                                     Stairs       0.00      0.00      0.00        64
#                          Stationary object       0.00      0.00      0.00       179
#                   Street, roadway, highway       0.00      0.00      0.00        96
#                    Struck animal or object       0.29      0.62      0.39      1555
#                  Struck building, overhang       0.14      0.01      0.02       330
#                    Struck dock/garage door       0.00      0.00      0.00       120
#                  Struck dumpster enclosure       1.00      0.01      0.01       183
#                             Struck mailbox       1.00      0.01      0.02       228
#                              Struck object       0.00      0.00      0.00        31
#                      Struck parked vehicle       0.49      0.52      0.50      1379
#                 Struck pedestrian, bicycle       1.00      0.01      0.02        99
#                     Struck vehicle in rear       0.55      0.57      0.56      1493
#                   Struck/pulled down wires       0.84      0.31      0.46       323
#    Sudden stop or start, injuring occupant       0.95      0.47      0.63        79
#                                      Theft       0.53      0.18      0.27       233
#                          Tree, bush, shrub       0.00      0.00      0.00        36
#                             Uneven Surface       0.00      0.00      0.00        73
#   Vandalism and Malicious Mischief - Prop.       1.00      0.01      0.03        75
#    Vandalism and malicious mischief - W.C.       0.00      0.00      0.00        52
#          Vehicle - Operated by other party       0.00      0.00      0.00        46
#                     Vehicle - Tire/Retread       0.00      0.00      0.00        25
#                              Vehicle - bus       0.00      0.00      0.00        10
#                        Vehicle - passenger       0.00      0.00      0.00        95
#        Vehicle - tractor, for semi trailer       0.00      0.00      0.00        39
#                   Vehicle - truck/snowplow       0.00      0.00      0.00        66
#                           Vehicle Accident       0.00      0.00      0.00       382
#                        Vehicle, unlicensed       0.00      0.00      0.00        43
#                       Walk, path, sidewalk       0.00      0.00      0.00        81
#                                      Water       0.00      0.00      0.00       139
#                                     Weapon       0.00      0.00      0.00        24
#                     Weather NOC - Property       0.00      0.00      0.00        40
#                                       Wind       0.00      0.00      0.00        23
#                                 Windshield       0.69      0.06      0.11       183
#                                  Windstorm       0.80      0.04      0.07       103
#                             Wrongful entry       0.00      0.00      0.00        26
#                                 e-Commerce       0.89      0.52      0.65       433
#                                        med       0.35      0.21      0.26      1257
#
#                                   accuracy                           0.35     32798
#                                  macro avg       0.20      0.06      0.07     32798
#                               weighted avg       0.37      0.35      0.27     32798
#
# ****************************************************************************************************

# %% [markdown]
# ##### Model 2 - logistic regression

# %% [markdown]
# #### Using bert for embedding :

# %%
# pip install -U sentence-transformers

# %%
from sentence_transformers import SentenceTransformer
sentences = ["This is an example sentence", "Each sentence is converted"]

model = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2')
# Out:
# Downloading (…)e9125/.gitattributes:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading (…)_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading (…)7e55de9125/README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# Downloading (…)55de9125/config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# Downloading (…)ce_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Downloading (…)125/data_config.json:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Downloading (…)nce_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading (…)e9125/tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# Downloading (…)9125/train_script.py:   0%|          | 0.00/13.2k [00:00<?, ?B/s]
# Downloading (…)7e55de9125/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)5de9125/modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]

# %%
X = final_data['Claim Description'].values
y = final_data['Accident Source']

# %%
X_bert_enc = model.encode(X, batch_size=500, show_progress_bar=True,)
print(X_bert_enc.shape)
# Out:
# Batches:   0%|          | 0/328 [00:00<?, ?it/s]
# (163990, 384)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_bert_enc, y, test_size=0.20)

# %%
from sklearn.linear_model import LogisticRegression

lr_basemodel =LogisticRegression()

lr_basemodel.fit(X_train, y_train)
print("Model trained")

# save model
path = "results/lr_as_step_1.pickle"
pickle.dump(lr_basemodel, open(path, "wb"))
print("Model saved to", path)

# predict
y_pred = lr_basemodel.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print('Accuracy for logistic regression :',np.round(accuracy,2))

print("*"*100)

target_names = lr_basemodel.classes_
print(classification_report(y_test, y_pred, target_names=target_names))
print('*'*100)
# Out:
# Model trained
# Model saved to results/lr_as_step_1.pickle
# Accuracy for logistic regression : 0.45
# ****************************************************************************************************
#                                             precision    recall  f1-score   support
#
#     Accidental disposal of property/object       0.18      0.10      0.12       105
#                    Administrative Decision       0.67      0.31      0.42        26
#                     Alleged Discrimination       0.25      0.12      0.17        24
#                           Alleged Incident       0.00      0.00      0.00        18
#       Alleged Misconduct - Personal Injury       0.69      0.36      0.47        25
#                      Alleged Negligent Act       0.37      0.61      0.46      4021
#                    Alleged concrete defect       0.00      0.00      0.00        20
#          Alleged contamination or spoilage       0.55      0.54      0.54       396
#       Alleged damage to property of others       0.47      0.21      0.29       393
#                Alleged design flaw, defect       0.47      0.45      0.46       342
#          Alleged foreign object in product       0.62      0.72      0.67       485
#   Alleged improper maintenance - municipal       0.14      0.03      0.04        76
#       Alleged improper maintenance - other       0.34      0.29      0.31       996
#     Alleged improper maintenance - schools       0.33      0.05      0.08        21
#    Alleged installation by vendor/retailer       0.90      0.51      0.66        37
#                   Alleged lack of security       0.14      0.05      0.07        44
#        Alleged lack of supervision - other       0.00      0.00      0.00        39
#      Alleged lack of supervision - schools       0.45      0.47      0.46        72
#       Alleged mechanical defect of failure       0.35      0.17      0.23        36
#                  Alleged product loss, NOC       0.70      0.54      0.61       117
# Alleged service or maint.- vendor/retailer       0.33      0.10      0.16       248
# Alleged service or maintenance by customer       0.00      0.00      0.00        24
#                          Allergic Reaction       0.58      0.54      0.56        78
#                             Animal, Insect       0.56      0.43      0.49       139
#                                    Assault       0.32      0.16      0.21       114
#                       Assault and/or abuse       0.23      0.11      0.14        47
#                Assault during apprehension       0.33      0.11      0.17        36
#              Backed into vehicle or object       0.51      0.65      0.57      1228
#                                   Bathroom       0.28      0.16      0.20        45
#                     Box, barrel, container       0.24      0.15      0.18        54
#                     Building services, NOC       0.00      0.00      0.00        26
#        Burglary, Robbery, Theft - Property       0.62      0.13      0.22        60
#                   Burglary, robbery, theft       0.34      0.35      0.34       189
#                                   Car Wash       0.66      0.61      0.63       117
#                                   Car stop       0.29      0.28      0.29        36
#                                       Cart       0.63      0.71      0.67       446
#                                  Collision       0.32      0.28      0.30        32
#                  Collision on a Roundabout       0.85      0.72      0.78        39
#                         DEFECTIVE PAVEMENT       0.55      0.78      0.65        46
#                          DEFECTIVE PRODUCT       0.00      0.00      0.00        33
#                      Damage to landscaping       0.61      0.63      0.62       283
#                                    Display       0.27      0.09      0.13        67
#                              Door - Office       0.18      0.12      0.14        17
# Elevator,escalator,manlift,moving sidewalk       0.60      0.49      0.54        55
#                         Elevator/Escalator       0.27      0.12      0.17        24
#           Entering or leaving traffic flow       0.31      0.13      0.18       123
#                      Equipment Malfunction       0.28      0.10      0.15        69
#                 Excavation, trench, tunnel       1.00      0.18      0.31        22
#                        Extreme temperature       0.29      0.07      0.11        30
#                             Falling Object       0.07      0.03      0.04       115
#                                Fire - Auto       0.56      0.44      0.49        85
#                            Fire - Property       0.23      0.23      0.23        47
#                               Food Product       0.44      0.35      0.39       318
#                      Foreign object thrown       0.04      0.02      0.02        58
#   Freezing of Plumbing, Heating, AC System       0.54      0.61      0.57       102
#                         Furniture, fixture       0.22      0.06      0.09        85
#                             Gasoline spill       0.26      0.18      0.21        45
#                                Gate, fence       0.20      0.11      0.14        70
#                        Glass, ceramic, NOC       0.54      0.50      0.52        40
#                               Ground/floor       0.22      0.19      0.21       374
#                                       Hail       0.69      0.86      0.77        44
#                          Head-on collision       0.28      0.22      0.25        86
#                              Health Hazard       0.18      0.08      0.11        39
#                 Hit Post/Barrier/Gate/Pole       0.61      0.43      0.50        47
#                    Hit Third Party In Rear       0.46      0.38      0.41        32
#                             Hit Wall/Fence       0.80      0.46      0.59        26
#                 Hit in Rear by Third Party       0.36      0.34      0.35        29
#                          Human Action, NOC       0.34      0.21      0.26       388
#                Ice, Snow, Sleet - Property       0.00      0.00      0.00        28
#                    Ice, Snow, Sleet - W.C.       1.00      0.03      0.07        29
#                                  Ice/water       0.19      0.10      0.13       262
#   Injured while entering/alighting vehicle       0.58      0.48      0.52        71
#                      Insured Changed Lanes       0.58      0.24      0.34        29
#                      Insured Hit Parked TP       0.50      0.44      0.47        48
#                   Insured Reversing Hit TP       0.55      0.50      0.52        34
#      Insured vehicle causes other accident       0.00      0.00      0.00        20
#                      Intersection accident       0.48      0.49      0.48       851
#     Jacknife, rollover, overturned vehicle       0.45      0.37      0.41        82
#                         Malicious Mischief       1.00      0.04      0.08        25
#                                Merchandise       0.13      0.07      0.09        83
#                      Merchandises on Floor       0.38      0.09      0.15        55
#                            Metal item, NOC       0.27      0.12      0.16        52
#                                Mold/mildew       0.65      0.49      0.56        41
#     Non Liability Cases - Premises Medical       0.67      0.36      0.47       104
#                       Non-contact accident       0.44      0.17      0.25        81
#                   Not Otherwise Classified       0.24      0.26      0.25      1413
#         Object fall - loading or unloading       0.15      0.03      0.05        60
#                            Object on floor       0.29      0.14      0.19       133
#                              Oil or grease       0.59      0.51      0.55        78
#                      Other - comprehensive       0.29      0.14      0.19       339
#                 Other vehicle turning left       0.18      0.02      0.04        83
#                Other vehicle turning right       0.17      0.03      0.05        38
#                    Our vehicle backed into       0.32      0.11      0.16       212
#     Our vehicle struck by object or animal       0.25      0.05      0.09       164
#      Our vehicle struck by runaway vehicle       0.08      0.04      0.05        50
#                 Our vehicle struck in rear       0.52      0.44      0.48       769
#            Our vehicle struck while parked       0.36      0.19      0.25       288
#                   Our vehicle turning left       0.31      0.21      0.25       182
#                  Our vehicle turning right       0.19      0.12      0.15       109
#                                     Pallet       0.33      0.49      0.39        35
#                       Pallet Jack (manual)       0.62      0.31      0.42        32
#                      Parking lot, driveway       0.37      0.20      0.26       265
#                    Particle/Foreign Object       0.00      0.00      0.00        35
#  Plumbing,Heating,AC,Discharge,Overflowing       0.43      0.49      0.45       206
#                                    Pothole       0.67      0.80      0.73        61
#                                       Rain       0.45      0.36      0.40        53
#                            Ran off roadway       0.40      0.27      0.32        77
#                    Road debris/road hazard       0.61      0.58      0.60       284
#                            Runaway vehicle       0.00      0.00      0.00        25
#                              Scrap, debris       0.00      0.00      0.00        27
# Sharps(Needles,Razors,Scissors,Knife,etc.)       0.11      0.04      0.06        27
#                   Sideswipe or lane change       0.54      0.69      0.60      3112
#   Sprinkler Leakage - Pipe or Head Failure       0.37      0.33      0.34        46
#                                     Stairs       0.35      0.26      0.30        62
#                          Stationary object       0.03      0.01      0.01       173
#                   Street, roadway, highway       0.13      0.02      0.04        99
#                    Struck animal or object       0.45      0.55      0.49      1519
#                  Struck building, overhang       0.48      0.40      0.44       333
#                    Struck dock/garage door       0.35      0.34      0.34       106
#                  Struck dumpster enclosure       0.55      0.54      0.55       182
#                             Struck mailbox       0.81      0.82      0.81       214
#                              Struck object       0.33      0.09      0.14        23
#                      Struck parked vehicle       0.58      0.62      0.60      1357
#                 Struck pedestrian, bicycle       0.66      0.51      0.58       107
#                     Struck vehicle in rear       0.58      0.62      0.60      1536
#                   Struck/pulled down wires       0.82      0.82      0.82       313
#    Sudden stop or start, injuring occupant       0.68      0.65      0.66        83
#                                      Theft       0.41      0.53      0.46       222
#                          Tree, bush, shrub       0.52      0.42      0.47        52
#                             Uneven Surface       0.24      0.10      0.14        79
#   Vandalism and Malicious Mischief - Prop.       0.26      0.17      0.21        80
#    Vandalism and malicious mischief - W.C.       0.28      0.11      0.16        70
#          Vehicle - Operated by other party       0.00      0.00      0.00        31
#                     Vehicle - Tire/Retread       0.17      0.17      0.17        23
#                              Vehicle - bus       0.17      0.05      0.08        20
#                        Vehicle - passenger       0.25      0.06      0.10        85
#        Vehicle - tractor, for semi trailer       0.00      0.00      0.00        42
#                   Vehicle - truck/snowplow       0.14      0.01      0.02        76
#                           Vehicle Accident       0.27      0.14      0.19       399
#                        Vehicle, unlicensed       0.28      0.11      0.16        45
#                       Walk, path, sidewalk       0.18      0.03      0.05        71
#                                      Water       0.33      0.20      0.25       149
#                                     Weapon       0.50      0.08      0.14        24
#                     Weather NOC - Property       0.57      0.33      0.42        48
#                                       Wind       0.00      0.00      0.00        26
#                                 Windshield       0.52      0.60      0.56       177
#                                  Windstorm       0.57      0.63      0.60       105
#                             Wrongful entry       0.00      0.00      0.00        16
#                                 e-Commerce       0.75      0.83      0.79       472
#                                        med       0.30      0.30      0.30      1231
#
#                                   accuracy                           0.45     32798
#                                  macro avg       0.38      0.28      0.30     32798
#                               weighted avg       0.43      0.45      0.43     32798
#
# ****************************************************************************************************

# %%
# pickle.dump(count_vector_step_1, open("./vectorizer/count_vector_step_1.pickel","wb"))
# pickle.dump(count_vector_step_2, open("./vectorizer/count_vector_step_2.pickel","wb"))
# pickle.dump(count_vector_as_step_1, open("./vectorizer/count_vector_as_step_1.pickel","wb"))

# %% [markdown]
# ### Conclusion :
#
# - Coverage code :
#     - For coverage code we use two models for prediction.
#     - Also we check if feature is in dictionary.
#
# - Accident source :
#     - We use bert embedding.
#     - And then train simple logistic regression model on top of it.
#
# - We deployed this model on streamlt.
#
# https://huggingface.co/spaces/mahesh3394/gallegher_insurance_app
